# %% [markdown]
# # e-rara: accessing metadata and fulltexts

# %% [markdown]
# <h1><span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#0-Introduction" data-toc-modified-id="0-Introduction-1">0 Introduction</a></span><ul class="toc-item"><li><span><a href="#0.0-Scope-and-content" data-toc-modified-id="0.0-Scope-and-content-1.1">0.0 Scope and content</a></span></li><li><span><a href="#0.1-E-rara" data-toc-modified-id="0.1-E-rara-1.2">0.1 E-rara</a></span></li><li><span><a href="#0.2-OAI-PMH" data-toc-modified-id="0.2-OAI-PMH-1.3">0.2 OAI-PMH</a></span></li></ul></li><li><span><a href="#1-Metadata-access-with-Polymatheia" data-toc-modified-id="1-Metadata-access-with-Polymatheia-2">1 Metadata access with Polymatheia</a></span><ul class="toc-item"><li><span><a href="#1.0-Prerequisites" data-toc-modified-id="1.0-Prerequisites-2.1">1.0 Prerequisites</a></span></li><li><span><a href="#1.1-Start-with-the-OAI-interface-via-Polymatheia" data-toc-modified-id="1.1-Start-with-the-OAI-interface-via-Polymatheia-2.2">1.1 Start with the OAI interface via Polymatheia</a></span></li><li><span><a href="#1.2-Retrieve-metadata-records-via-Polymatheia" data-toc-modified-id="1.2-Retrieve-metadata-records-via-Polymatheia-2.3">1.2 Retrieve metadata records via Polymatheia</a></span></li><li><span><a href="#1.3-Retrieve-the-licences" data-toc-modified-id="1.3-Retrieve-the-licences-2.4">1.3 Retrieve the licences</a></span></li><li><span><a href="#1.4-Save--and-recover-complex-metadata-structures" data-toc-modified-id="1.4-Save--and-recover-complex-metadata-structures-2.5">1.4 Save  and recover complex metadata structures</a></span></li></ul></li><li><span><a href="#2-Direct-metadata-access-via-OAI-PMH" data-toc-modified-id="2-Direct-metadata-access-via-OAI-PMH-3">2 Direct metadata access via OAI-PMH</a></span><ul class="toc-item"><li><span><a href="#2.0-Prerequisites" data-toc-modified-id="2.0-Prerequisites-3.1">2.0 Prerequisites</a></span></li><li><span><a href="#2.1-Start-with-the-native-OAI-interface" data-toc-modified-id="2.1-Start-with-the-native-OAI-interface-3.2">2.1 Start with the native OAI interface</a></span></li><li><span><a href="#2.2-Download-metadata-records" data-toc-modified-id="2.2-Download-metadata-records-3.3">2.2 Download metadata records</a></span></li><li><span><a href="#2.3-Get-set-size-&amp;-download-metadata-by-set" data-toc-modified-id="2.3-Get-set-size-&amp;-download-metadata-by-set-3.4">2.3 Get set size &amp; download metadata by set</a></span></li></ul></li><li><span><a href="#3-Download-fulltext-files-from-e-rara-website" data-toc-modified-id="3-Download-fulltext-files-from-e-rara-website-4">3 Download fulltext files from e-rara website</a></span><ul class="toc-item"><li><span><a href="#3.0-Prerequisites" data-toc-modified-id="3.0-Prerequisites-4.1">3.0 Prerequisites</a></span></li><li><span><a href="#3.1-Download-fulltext-files-by-e-rara-ID" data-toc-modified-id="3.1-Download-fulltext-files-by-e-rara-ID-4.2">3.1 Download fulltext files by e-rara ID</a></span></li><li><span><a href="#3.2-Download-fulltext-files-by-set" data-toc-modified-id="3.2-Download-fulltext-files-by-set-4.3">3.2 Download fulltext files by set</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## 0 Introduction

# %% [markdown]
# ### 0.0 Scope and content

# %% [markdown]
# This Python [Jupyter notebook](https://jupyter.org/) aims to help you with **accessing metadata and fulltexts of the [e-rara platform](https://www.e-rara.ch/)**. It uses the OAI-PMH interface of the e-rara service for retrieving metadata in different formats, and the e-rara website in addition for downloading fulltexts.
#
# The notebook consists of three parts:
# 1. Metadata access with Polymatheia
# 2. Direct metadata access via OAI-PMH
# 3. Download fulltext files from e-rara website.
#
# So, there are two ways to access e-rara metadata. The **first chapter** introduces the Polymatheia library, which allows very convenient requests to the OAI interface by wrapping otherwise more elaborate functions. Working with Polymatheia is an **easy solution for quick access** without going deep into coding.
#
# The **second (and the third) chapter** shows how to access the OAI interface natively. Hence, more code will be needed and **some functions will be defined**. You can use the functions without deeper programming skills - nevertheless these might be helpful if you want to adapt those functions.
#
# You may start from the beginning and walk trough the whole notebook or jump to the section that suits you. Also, it's a good idea to play around with the code in the cells and see what happens. Have fun!
#
# Have any comments, questions and the like? Try kathi.woitas[at]ub.unibe.ch.

# %% [markdown]
# ### 0.1 E-rara

# %% [markdown]
# [E-rara](https://www.e-rara.ch/) is the platform for digitized rare prints from Swiss institutions. E-rara holds approximately 60k old books, 17k printed graphic works, 6600 maps and 700 music prints as image files, in PDF format and partly as TXT files. You may consult e-rara's [Terms of Use](https://www.e-rara.ch/wiki/termsOfUse?lang=en) to check the licences of the e-rara documents.

# %% [markdown]
# ### 0.2 OAI-PMH

# %% [markdown]
# The **Open Archives Initiative Protocol for Metadata Harvesting** (**OAI-PMH**) is a well-known interface for libraries,
# archives etc. for delivering their metadata in various formats, librarian's specific like [MODS](http://www.loc.gov/standards/mods/index.html) and common ones like [Dublin Core](https://www.dublincore.org/specifications/dublin-core/dces/) alike.
# Further information on OAI-PMH is available [here](http://www.openarchives.org/OAI/openarchivesprotocol.html).
#
# First of all, a few OAI-PMH related concepts should be introduced:
#
# **repository**:
# A repository is a server-side application that exposes metadata via OAI-PMH. It can process the *six OAI-PMH request types* aka *OAI verbs*. So, the e-rara OAI-PMH facility is a repository in this sense.
#
# **harvester**: OAI-PMH client applications are called harvesters. When you are approaching the OAI-PMH interface and requesting records, you do *harvesting*.
#
# **resource**: A resource is the object that the delivered metadata is "about". Of course in case of e-rara OAI-PMH, the referred resources are the publications of the e-rara platform. Note that resources themselves are always outside of the OAI-PMH.
#
# **record**: A record is the XML-encoded container for the metadata of a single resource (i.e. publication) item. It consists of a header and a metadata section.
#
# **header**:
# The record header contains the unique identifier of the record, a datestamp and optionally the set specification.
#
# **metadata**: The record metadata contains the resource (i.e. publication) metadata in a defined metadata format.
#
# **set**: A structure for grouping records for selective harvesting. Sets often refer to collections of thematic scopes/subjects, to collections of different owners/institutions (in case of aggregated content) or to collections of certain publication types.
#
# Now let's look at some example requests of the e-rara OAI interface with the **six OAI verbs**:
#
# - Identify ([specification](http://www.openarchives.org/OAI/openarchivesprotocol.html#Identify)):
#  https://www.e-rara.ch/oai?verb=Identify
#
# - ListSets ([spec](http://www.openarchives.org/OAI/openarchivesprotocol.html#ListSets)):
# https://www.e-rara.ch/oai?verb=ListSets
#
# - ListMetadataFormats ([spec](http://www.openarchives.org/OAI/openarchivesprotocol.html#ListMetadataFormats)):
# https://www.e-rara.ch/oai?verb=ListMetadataFormats
#
# - ListIdentifiers ([spec](http://www.openarchives.org/OAI/openarchivesprotocol.html#ListIdentifiers)):
# https://www.e-rara.ch/oai?verb=ListIdentifiers&metadataPrefix=mods&set=bernensia
#
# - GetRecord ([spec](http://www.openarchives.org/OAI/openarchivesprotocol.html#GetRecord)):
# https://www.e-rara.ch/oai?verb=GetRecord&metadataPrefix=mods&identifier=23216296
#
# - ListRecords ([spec](http://www.openarchives.org/OAI/openarchivesprotocol.html#ListRecords)):
# https://www.e-rara.ch/oai?verb=ListRecords&from=1900-01-01&set=bernensia&metadataPrefix=oai_dc
#
# These examples with the given *parameters* are somewhat easy to encode - and so is building similar request URLs.
# But how to download the delivered data and to interact with it? That's the aim of this notebook. So, here we go!

# %% [markdown]
# ## 1 Metadata access with Polymatheia

# %% [markdown]
# ### 1.0 Prerequisites

# %% [markdown]
# First, some basic Python libraries have to be imported. Just **click on the arrow icon** on the left side of the code cell - or first click into the cell and then select 'Crtl' + 'Enter' or 'Shift' + 'Enter'. When the code runs, a star symbol next to the cell appears and when it's done a number turns up. And most important, the provoked output is given beneath the code cell.

# %%
import os                              # navigate and manipulate file directories
import pandas as pd                    # pandas is the Python standard library to work with dataframes
from IPython.display import IFrame     # embed website views in Jupyter notebook
print("Successfully imported necessary libraries")
# Out:
# Successfully imported necessary libraries

# %% [markdown]
# **Polymatheia** is a Python library to support working with digital library/archive metadata. It supports accessing metadata of different formats from OAI-PMH and also offers methods to handle the retrieved data. The metadata will be turned into a Python-style ['navigable dictionary'](https://polymatheia.readthedocs.io/en/latest/concepts.html), which allows convenient access to certain metadata fields.
# Its aim is not necessarily to cover all ways of working with metadata, but to make it easy to undertake most types of tasks and analysis. See the [documentation](https://polymatheia.readthedocs.io/en/latest/) of the Polymatheia library.
#
# Using Polymatheia package **for the first time**, you will need to **install this code library**: Just remove the `#` from the second line of code, and then execute the cell like the one before.

# %%
# uncomment !pip command to install polymatheia 
#!pip install polymatheia          
from polymatheia.data.reader import OAISetReader               # list OAI sets
from polymatheia.data.reader import OAIMetadataFormatReader    # list available metadata formats
from polymatheia.data.reader import OAIRecordReader            # read one metadata record from OAI
from polymatheia.data.writer import PandasDFWriter             # easy transformation of flat data into a dataframe
print("Successfully imported necessary libraries")
# Out:
# Successfully imported necessary libraries

# %% [markdown]
# https://www.e-rara.ch/oai/ will be the **base URL** for all OAI requests. To make life easier we put it into the variable `oai`.

# %%
oai = 'https://www.e-rara.ch/oai/'

# %% [markdown]
# ### 1.1 Start with the OAI interface via Polymatheia

# %% [markdown]
# First, it's good to know **which sets are available**. To take a look at the sets from the native OAI interface let's take a look of https://www.e-rara.ch/bes_1/oai?verb=ListSets with the `IFrame` function. For every set, there is the `setName`, and a `setSpec`, which is a short cut for the set name and will be used as parameter with the OAI accesses.

# %%
IFrame('https://www.e-rara.ch/oai?verb=ListSets', width=970, height=300)
# Out:
#         <iframe
#             width="970"
#             height="300"
#             src="https://www.e-rara.ch/oai?verb=ListSets"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# That's nice, but how to retrieve these contents as data? Polymatheia's 'OAISetReader' does this conveniently. Here's how it works.

# %%
reader = OAISetReader(oai)             # instantiate ('make') a OAISetReader named reader
# 'Instantiation' is a standard procedure with Python - so it's a good idea to get familiar with it.

print(type(reader))                    # print the object type of 'reader' for information
# Out:
# <class 'polymatheia.data.reader.OAISetReader'>

# %%
for x in reader:                       # for-loop which iterates through the reader-content and prints each
    print(x)                           # note that 'x' is an arbitrary term
# Out:
# {
#   "setSpec": "frc_g",
#   "setName": "BCU Fribourg (GLN)"
# }
# {
#   "setSpec": "elibch",
#   "setName": "Alle Bibliotheken"
# }
# {
#   "setSpec": "zbs",
#   "setName": "Zentralbibliothek Solothurn"
# }
# {
#   "setSpec": "sbs",
#   "setName": "Stadtbibliothek Schaffhausen"
# }
# {
#   "setSpec": "astrorara",
#   "setName": "Astronomie-rara"
# }
# {
#   "setSpec": "bau_1",
#   "setName": "UB Basel (DSV01)"
# }
# {
#   "setSpec": "kbg",
#   "setName": "Kantonsbibliothek Graub\u00fcnden"
# }
# {
#   "setSpec": "nep_r",
#   "setName": "Biblioth\u00e8que des Pasteurs, BPU Neuch\u00e2tel (RERO)"
# }
# {
#   "setSpec": "astrozut",
#   "setName": "ETH-Bibliothek Z\u00fcrich"
# }
# {
#   "setSpec": "frc_r",
#   "setName": "BCU Fribourg (RERO)"
# }
# {
#   "setSpec": "ebs",
#   "setName": "Eisenbibliothek Schlatt"
# }
# {
#   "setSpec": "nep_g",
#   "setName": "Biblioth\u00e8que des Pasteurs, BPU Neuch\u00e2tel (GLN)"
# }
# {
#   "setSpec": "lg1",
#   "setName": "Biblioteca Salita dei Frati, Lugano"
# }
# {
#   "setSpec": "demusmu",
#   "setName": "Deutsches Museum, M\u00fcnchen"
# }
# {
#   "setSpec": "ge88",
#   "setName": "Institut et Mus\u00e9e Voltaire, Gen\u00e8ve"
# }
# {
#   "setSpec": "lac1_g",
#   "setName": "BCU Lausanne (GLN)"
# }
# {
#   "setSpec": "cgj",
#   "setName": "C.G. Jung"
# }
# {
#   "setSpec": "mhr_g",
#   "setName": "Mus\u00e9e historique de la R\u00e9formation, Gen\u00e8ve (GLN)"
# }
# {
#   "setSpec": "snm",
#   "setName": "Schweizerisches Nationalmuseum"
# }
# {
#   "setSpec": "zhdk",
#   "setName": "Z\u00fcrcher Hochschule der K\u00fcnste"
# }
# {
#   "setSpec": "mhr_r",
#   "setName": "Mus\u00e9e historique de la R\u00e9formation, Gen\u00e8ve (RERO)"
# }
# {
#   "setSpec": "mab",
#   "setName": "Bibliothek der Musik-Akademie Basel"
# }
# {
#   "setSpec": "lac1_r",
#   "setName": "BCU Lausanne (RERO)"
# }
# {
#   "setSpec": "sikjm",
#   "setName": "Schweizerisches Institut f\u00fcr Kinder- und Jugendmedien SIKJM"
# }
# {
#   "setSpec": "oec",
#   "setName": "Stiftung Bibliothek Werner Oechslin, Einsiedeln"
# }
# {
#   "setSpec": "supsi",
#   "setName": "Biblioteca SUPSI DFA, Locarno"
# }
# {
#   "setSpec": "bes_5",
#   "setName": "UB Bern (NEBIS)"
# }
# {
#   "setSpec": "zut",
#   "setName": "ETH-Bibliothek (NEBIS)"
# }
# {
#   "setSpec": "bes_1",
#   "setName": "UB Bern (DSV01)"
# }
# {
#   "setSpec": "nev_g",
#   "setName": "BPU Neuch\u00e2tel (GLN)"
# }
# {
#   "setSpec": "gep_r",
#   "setName": "Biblioth\u00e8que de Gen\u00e8ve (RERO)"
# }
# {
#   "setSpec": "zuz",
#   "setName": "ZB Z\u00fcrich (NEBIS)"
# }
# {
#   "setSpec": "zhb",
#   "setName": "Zentral- & Hochschulbibliothek Luzern"
# }
# {
#   "setSpec": "stp",
#   "setName": "Stiftung Pestalozzianum"
# }
# {
#   "setSpec": "erara",
#   "setName": "e-rara"
# }
# {
#   "setSpec": "nev_r",
#   "setName": "BPU Neuch\u00e2tel (RERO)"
# }
# {
#   "setSpec": "gep_g",
#   "setName": "Biblioth\u00e8que de Gen\u00e8ve (GLN)"
# }
# {
#   "setSpec": "ch15",
#   "setName": "Schweizer Drucke des 15. Jahrhunderts"
# }
# {
#   "setSpec": "ch16",
#   "setName": "Schweizer Drucke des 16. Jahrhunderts"
# }
# {
#   "setSpec": "alch",
#   "setName": "Alchemie, Magie und Kabbala (Stiftung der Werke von C.G. Jung, Z\u00fcrich)"
# }
# {
#   "setSpec": "ch",
#   "setName": "Schweizer Drucke"
# }
# {
#   "setSpec": "ch17",
#   "setName": "Schweizer Drucke des 17. Jahrhunderts"
# }
# {
#   "setSpec": "solothurn",
#   "setName": "Alte Drucke aus Solothurn (ZB Solothurn)"
# }
# {
#   "setSpec": "ch18",
#   "setName": "Schweizer Drucke des 18. Jahrhunderts"
# }
# {
#   "setSpec": "anatomie",
#   "setName": "Anatomie (BPU Neuch\u00e2tel)"
# }
# {
#   "setSpec": "ch19",
#   "setName": "Schweizer Drucke des 19. Jahrhunderts\n \n"
# }
# {
#   "setSpec": "ch20",
#   "setName": "Schweizer Drucke des 20. Jahrhunderts"
# }
# {
#   "setSpec": "bernensia",
#   "setName": "Bernensia des 18. bis fr\u00fchen 20. Jahrhunderts (UB Bern)"
# }
# {
#   "setSpec": "bibleikon",
#   "setName": "Bibleikon (Biblioth\u00e8que des Pasteurs, BPU Neuch\u00e2tel)"
# }
# {
#   "setSpec": "nagezh",
#   "setName": "Bibliothek der Naturforschenden Gesellschaft Z\u00fcrich (ZB Z\u00fcrich)"
# }
# {
#   "setSpec": "flug",
#   "setName": "Flugschriften"
# }
# {
#   "setSpec": "fondo",
#   "setName": "Fondo Gianini (Biblioteca SUPSI DFA, Locarno)"
# }
# {
#   "setSpec": "brochgenevoises",
#   "setName": "Genfer Brosch\u00fcren"
# }
# {
#   "setSpec": "italpoet",
#   "setName": "Italienische Poesie und Prosa des 17. Jahrhunderts (Biblioteca Salita dei Frati, Lugano)"
# }
# {
#   "setSpec": "collections",
#   "setName": "Themen und Sammlungen"
# }
# {
#   "setSpec": "rheinau",
#   "setName": "Kloster Rheinau (ZB Z\u00fcrich)"
# }
# {
#   "setSpec": "rossica",
#   "setName": "Rossica Europeana (UB Bern)"
# }
# {
#   "setSpec": "russexil",
#   "setName": "Russisches Schrifttum im Exil (UB Bern)"
# }
# {
#   "setSpec": "sikjmc",
#   "setName": "Schweizer Kinder- und Jugendb\u00fccher (Schweizerisches Institut f\u00fcr Kinder- und Jugendmedien SIKJM)"
# }
# {
#   "setSpec": "tewi",
#   "setName": "Technik- und Wissenschaftsgeschichte (Eisenbibliothek)"
# }
# {
#   "setSpec": "ticinensia",
#   "setName": "Tessiner Editionen des 18. und 19. Jahrhunderts (Biblioteca Salita dei Frati, Lugano)"
# }
# {
#   "setSpec": "vitruviana",
#   "setName": "Vitruviana (Stiftung Bibliothek Werner Oechslin, Einsiedeln)"
# }
# {
#   "setSpec": "oiseaux",
#   "setName": "Vogelb\u00fccher (BPU Neuch\u00e2tel)"
# }
# {
#   "setSpec": "rousseau",
#   "setName": "Werke von Jean-Jacques Rousseau (Biblioth\u00e8que de Gen\u00e8ve)"
# }
# {
#   "setSpec": "profethz",
#   "setName": "Werke von Professoren der ETH Z\u00fcrich (ETH-Bibliothek)"
# }
# {
#   "setSpec": "wihibe",
#   "setName": "Wissenschaftshistorische Best\u00e4nde (ETH-Bibliothek)"
# }
# {
#   "setSpec": "pbhzwingli",
#   "setName": "Huldrych Zwingli (1484\u20131531)"
# }
# {
#   "setSpec": "pbjwaser",
#   "setName": "Josias Waser (1598-1629)"
# }
# {
#   "setSpec": "pbjjbodmer",
#   "setName": "Johann Jakob Bodmer (1698\u20131783)"
# }
# {
#   "setSpec": "pbhkescher",
#   "setName": "Hans Konrad Escher von der Linth (1767-1823)"
# }
# {
#   "setSpec": "pboheer",
#   "setName": "Oswald Heer (1809-1883)"
# }
# {
#   "setSpec": "pbrwolf",
#   "setName": "Rudolf Wolf (1816-1893)"
# }
# {
#   "setSpec": "pbgkeller",
#   "setName": "Gottfried Keller (1819-1890)"
# }
# {
#   "setSpec": "pbawaldner",
#   "setName": "August Waldner (1844-1906)"
# }
# {
#   "setSpec": "pbifriedlaender",
#   "setName": "Immanuel Friedlaender (1871-1948)"
# }
# {
#   "setSpec": "collection25656349",
#   "setName": null
# }
# {
#   "setSpec": "privlib",
#   "setName": "Privatbibliotheken"
# }
# {
#   "setSpec": "doi",
#   "setName": "unknown spec"
# }
# {
#   "setSpec": "notated_music",
#   "setName": "notated music"
# }
# {
#   "setSpec": "book",
#   "setName": "book"
# }
# {
#   "setSpec": "illustration_document",
#   "setName": "illustration document"
# }
# {
#   "setSpec": "cartographic",
#   "setName": "cartographic"
# }

# %% [markdown]
# We might put this together and then turn the retrieved data into a *Pandas dataframe* with the 'PandasDFWriter' command. A **dataframe** is a table-like data object, which is a nice breakdown and moreover an useful format for further investigation. *Pandas* is the standard library in Python for dataframe handling.

# %%
reader = OAISetReader(oai)
setspec = []                          # make an empty list named 'setspec'

for x in reader:                 
    setspec.append(x)                 # .append adds all the single reader-contents to the list 'setspec'

print(setspec[0:3])                   # print the first 3 items of the list (of key-value pairs), just to see

df = PandasDFWriter().write(setspec)  # write list 'setspec' into a Pandas dataframe named 'df'
df                                    # shows 'df'
# Out:
# [{'setSpec': 'frc_g', 'setName': 'BCU Fribourg (GLN)'}, {'setSpec': 'elibch', 'setName': 'Alle Bibliotheken'}, {'setSpec': 'zbs', 'setName': 'Zentralbibliothek Solothurn'}]
#                   setSpec                       setName
# 0                   frc_g            BCU Fribourg (GLN)
# 1                  elibch             Alle Bibliotheken
# 2                     zbs   Zentralbibliothek Solothurn
# 3                     sbs  Stadtbibliothek Schaffhausen
# 4               astrorara               Astronomie-rara
# ..                    ...                           ...
# 77                    doi                  unknown spec
# 78          notated_music                 notated music
# 79                   book                          book
# 80  illustration_document         illustration document
# 81           cartographic                  cartographic
#
# [82 rows x 2 columns]

# %% [markdown]
# If a great number of sets are given, you might **search for a certain collection by string**. This can be also helpful to **get to know the set short cut** `setSpec` used by the OAI interface for further investigation of a certain set.

# %%
# Example: Searching for strings 'bern' or 'Bern' in the 'setName' column
for i in df.index:                                             # for-loop which iterates through 'df' contents
    if df.setName[i]:                                          # to exclude problematic 'None' content
        if 'bern' in df.setName[i] or 'Bern' in df.setName[i]: # if-condition which looks for 'bern'- or 'Bern'
                                                               # in the 'setName' column
            print(df.loc[i])                                       # print 'df' row, if if-condition is True
# Out:
# setSpec              bes_5
# setName    UB Bern (NEBIS)
# Name: 26, dtype: object
# setSpec              bes_1
# setName    UB Bern (DSV01)
# Name: 28, dtype: object
# setSpec                                            bernensia
# setName    Bernensia des 18. bis frühen 20. Jahrhunderts ...
# Name: 47, dtype: object
# setSpec                        rossica
# setName    Rossica Europeana (UB Bern)
# Name: 56, dtype: object
# setSpec                                   russexil
# setName    Russisches Schrifttum im Exil (UB Bern)
# Name: 57, dtype: object

# %%
# A nicer view to explore all given sets
df.style
# Out:
# <style  type="text/css" >
# </style><table id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >setSpec</th>        <th class="col_heading level0 col1" >setName</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001row0_col0" class="data row0 col0" >frc_g</td>
#                         <td id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001row0_col1" class="data row0 col1" >BCU Fribourg (GLN)</td>
#             </tr>
#             <tr>
#                         <th id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001row1_col0" class="data row1 col0" >elibch</td>
#                         <td id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001row1_col1" class="data row1 col1" >Alle Bibliotheken</td>
#             </tr>
#             <tr>
#                         <th id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001row2_col0" class="data row2 col0" >zbs</td>
#                         <td id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001row2_col1" class="data row2 col1" >Zentralbibliothek Solothurn</td>
#             </tr>
#             <tr>
#                         <th id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001row3_col0" class="data row3 col0" >sbs</td>
#                         <td id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001row3_col1" class="data row3 col1" >Stadtbibliothek Schaffhausen</td>
#             </tr>
#             <tr>
#                         <th id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001row4_col0" class="data row4 col0" >astrorara</td>
#                         <td id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001row4_col1" class="data row4 col1" >Astronomie-rara</td>
#             </tr>
#             <tr>
#                         <th id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001row5_col0" class="data row5 col0" >bau_1</td>
#                         <td id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001row5_col1" class="data row5 col1" >UB Basel (DSV01)</td>
#             </tr>
#             <tr>
#                         <th id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001row6_col0" class="data row6 col0" >kbg</td>
#                         <td id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001row6_col1" class="data row6 col1" >Kantonsbibliothek Graubünden</td>
#             </tr>
#             <tr>
#                         <th id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001row7_col0" class="data row7 col0" >nep_r</td>
#                         <td id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001row7_col1" class="data row7 col1" >Bibliothèque des Pasteurs, BPU Neuchâtel (RERO)</td>
#             </tr>
#             <tr>
#                         <th id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001row8_col0" class="data row8 col0" >astrozut</td>
#                         <td id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001row8_col1" class="data row8 col1" >ETH-Bibliothek Zürich</td>
#             </tr>
#             <tr>
#                         <th id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001row9_col0" class="data row9 col0" >frc_r</td>
#                         <td id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001row9_col1" class="data row9 col1" >BCU Fribourg (RERO)</td>
#             </tr>
#             <tr>
#                         <th id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001row10_col0" class="data row10 col0" >ebs</td>
#                         <td id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001row10_col1" class="data row10 col1" >Eisenbibliothek Schlatt</td>
#             </tr>
#             <tr>
#                         <th id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001row11_col0" class="data row11 col0" >nep_g</td>
#                         <td id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001row11_col1" class="data row11 col1" >Bibliothèque des Pasteurs, BPU Neuchâtel (GLN)</td>
#             </tr>
#             <tr>
#                         <th id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001row12_col0" class="data row12 col0" >lg1</td>
#                         <td id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001row12_col1" class="data row12 col1" >Biblioteca Salita dei Frati, Lugano</td>
#             </tr>
#             <tr>
#                         <th id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001row13_col0" class="data row13 col0" >demusmu</td>
#                         <td id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001row13_col1" class="data row13 col1" >Deutsches Museum, München</td>
#             </tr>
#             <tr>
#                         <th id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001row14_col0" class="data row14 col0" >ge88</td>
#                         <td id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001row14_col1" class="data row14 col1" >Institut et Musée Voltaire, Genève</td>
#             </tr>
#             <tr>
#                         <th id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001row15_col0" class="data row15 col0" >lac1_g</td>
#                         <td id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001row15_col1" class="data row15 col1" >BCU Lausanne (GLN)</td>
#             </tr>
#             <tr>
#                         <th id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001row16_col0" class="data row16 col0" >cgj</td>
#                         <td id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001row16_col1" class="data row16 col1" >C.G. Jung</td>
#             </tr>
#             <tr>
#                         <th id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001row17_col0" class="data row17 col0" >mhr_g</td>
#                         <td id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001row17_col1" class="data row17 col1" >Musée historique de la Réformation, Genève (GLN)</td>
#             </tr>
#             <tr>
#                         <th id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_08e4e72e_d440_11eb_b3dd_00090ffe0001row18_col0" class="data row18 col0" >snm</td>

# %% [markdown]
# It's also very useful to know in which **formats the metadata records** are available. The genuine interface does this by requesting the URL https://www.e-rara.ch/oai?verb=ListMetadataFormats. Here, we use the 'OAIMetadataFormatReader' of Polymatheia.
#
# As you might see, you can directly select some information like `metadataPrefix` and `metadataNamespace` from the retrieved data by **using the dot-notation**. Dot-notation just adds the desired subordinated element after a dot.

# %%
reader = OAIMetadataFormatReader(oai)
for formats in reader:
    print(formats)
    print(formats.metadataPrefix)    # dot-notation: chooses element 'metadataPrefix' from the reader content
    print('---')
# Out:
# {
#   "schema": "http://www.openarchives.org/OAI/2.0/oai_dc.xsd",
#   "metadataPrefix": "oai_dc",
#   "metadataNamespace": "http://www.openarchives.org/OAI/2.0/oai_dc/"
# }
# oai_dc
# ---
# {
#   "schema": "http://www.loc.gov/standards/mets/mets.xsd",
#   "metadataPrefix": "mets",
#   "metadataNamespace": "http://www.loc.gov/METS/"
# }
# mets
# ---
# {
#   "schema": "http://www.loc.gov/standards/mods/v3/mods-3-0.xsd",
#   "metadataPrefix": "mods",
#   "metadataNamespace": "http://www.loc.gov/mods/v3"
# }
# mods
# ---
# {
#   "schema": "http://www.loc.gov/standards/mods/v3/mods-3-0.xsd",
#   "metadataPrefix": "rawmods",
#   "metadataNamespace": "http://www.loc.gov/mods/v3"
# }
# rawmods
# ---
# {
#   "schema": "http://www.persistent-identifier.de/xepicur/version1.0/xepicur.xsd",
#   "metadataPrefix": "epicur",
#   "metadataNamespace": "urn:nbn:de:1111-2004033116"
# }
# epicur
# ---

# %%
reader = OAIMetadataFormatReader(oai)
[formats.metadataPrefix for formats in reader]   # shorter notation for the for-loops above, which outputs a list
# Out:
# ['oai_dc', 'mets', 'mods', 'rawmods', 'epicur']

# %% [markdown]
# ### 1.2 Retrieve metadata records via Polymatheia

# %% [markdown]
#  Retrieving available **metadata as a bunch** is simple with the 'OAIRecordReader' command. Just specify the following parameters in the 'OAIRecordReader' function.
#
# - `metadata_prefix`: mandatory
# - `set_spec` (the short cut for the set you want to retrieve): not mandatory, but default will be *all = many* available records!
# - `max_records` (the number of records): not mandatory, but default will be *all = many* available records!
#
# To compare this result with the native OAI interface you might check the top item of
# https://www.e-rara.ch/oai?verb=ListRecords&metadataPrefix=oai_dc&set=bernensia.

# %%
reader = OAIRecordReader(oai, metadata_prefix='oai_dc', set_spec='bernensia', max_records=1)
[record for record in reader]
# Out:
# [{'header': {'identifier': {'_text': 'oai:www.e-rara.ch:1395833'},
#    'datestamp': {'_text': '2012-09-26T14:23:16Z'},
#    'setSpec': [{'_text': 'bes_1'},
#     {'_text': 'journal'},
#     {'_text': 'collections'},
#     {'_text': 'bernensia'},
#     {'_text': 'ch'},
#     {'_text': 'ch19'}]},
#   'metadata': {'{http://www.openarchives.org/OAI/2.0/oai_dc/}dc': {'_attrib': {'xsi_schemaLocation': 'http://www.openarchives.org/OAI/2.0/oai_dc/ http://www.openarchives.org/OAI/2.0/oai_dc.xsd'},
#     'dc_title': {'_text': 'Adressbuch der Stadt Bern'},
#     'dc_creator': {'_text': '[s.n.]'},
#     'dc_description': [{'_text': '1860 - Jg. 75(1957)'},
#      {'_text': 'Mit Stadtplan (zuerst eingeklebt, später als lose Beilage)'}],
#     'dc_publisher': {'_text': 'Hallwag'},
#     'dc_date': [{'_text': '1860'}, {'_text': '1957'}],
#     'dc_type': [{'_text': 'Text'},
#      {'_text': 'Periodical'},
#      {'_text': 'Zeitschrift'}],
#     'dc_format': {'_text': '35 cm'},
#     'dc_identifier': [{'_text': 'doi:10.3931/e-rara-4614'},
#      {'_text': 'https://www.e-rara.ch/bes_1/doi/10.3931/e-rara-4614'},
#      {'_text': 'system:99116914771105511'}],
#     'dc_relation': [{'_text': 'vignette : https://www.e-rara.ch/bes_1/titlepage/doi/10.3931/e-rara-4614/128'},
#      {'_text': '003065432'}],
#     'dc_language': {'_text': 'ger'},
#     'dc_coverage': {'_text': '910'},
#     'dc_rights': {'_text': 'pdm'}}}}]

# %% [markdown]
# To access a certain metadata content, you can **follow down the *navigable dictionary* path** with dot-notation, like the following example.

# %%
reader = OAIRecordReader(oai, set_spec='bernensia', metadata_prefix='oai_dc', max_records=1)
for record in reader:
    print(record.header.identifier._text)        # compare to the first line of the output above
# Out:
# oai:www.e-rara.ch:1395833

# %% [markdown]
# Not always metadata content is a simple flat value like the identifier above. **Many fields in structured metadata formats are lists** as they hold multiple values. A good example is the `header` field `setSpec` which holds the information about the different OAI set memberships of the item.

# %%
reader = OAIRecordReader(oai, set_spec='bernensia', metadata_prefix='oai_dc', max_records=1)
for record in reader:
    print(record.header.setSpec)
# Out:
# [{'_text': 'bes_1'}, {'_text': 'journal'}, {'_text': 'collections'}, {'_text': 'bernensia'}, {'_text': 'ch'}, {'_text': 'ch19'}]

# %% [markdown]
# The surrounding square brackets `[ ]` indicate a list (here of key-value pairs). To access each content of the list items of its own you might use *subsetting*, which calls the relevant item by its number in the list.

# %%
reader = OAIRecordReader(oai, set_spec='bernensia', metadata_prefix='oai_dc', max_records=1)
for record in reader:
    print(record.header.setSpec[0]._text)
    print(record.header.setSpec[1]._text)
    print(record.header.setSpec[2]._text)
    print(record.header.setSpec[3]._text)
    print(record.header.setSpec[4]._text)
    print(record.header.setSpec[5]._text)
# Out:
# bes_1
# journal
# collections
# bernensia
# ch
# ch19

# %% [markdown]
# For retrieving contents from the `metadata` section a similar subsetting insertion has to be done according to its qualifying string `'{http://www.openarchives.org/OAI/2.0/oai_dc/}dc'`. To give some background information here: This string refers to the `metadataNamespace` element we've seen at retrieving the available metadata formats above.

# %%
reader = OAIRecordReader(oai, set_spec='bernensia', metadata_prefix='oai_dc', max_records=1)
for record in reader:
    print(record.metadata['{http://www.openarchives.org/OAI/2.0/oai_dc/}dc'].dc_title._text)
    print('---')
    print(record.metadata['{http://www.openarchives.org/OAI/2.0/oai_dc/}dc'].dc_identifier[0]._text)
    print(record.metadata['{http://www.openarchives.org/OAI/2.0/oai_dc/}dc'].dc_identifier[1]._text)
    print(record.metadata['{http://www.openarchives.org/OAI/2.0/oai_dc/}dc'].dc_identifier[2]._text)
# Out:
# Adressbuch der Stadt Bern
# ---
# doi:10.3931/e-rara-4614
# https://www.e-rara.ch/bes_1/doi/10.3931/e-rara-4614
# system:99116914771105511

# %% [markdown]
# Of course, MODS metadata is by far more rich in content. The request can easily be adjusted by the `metadata_prefix` parameter. But, as you might see in the title fields for instance, it also bears more complexity.

# %%
reader = OAIRecordReader(oai, metadata_prefix='mods', set_spec='bernensia', max_records=1)
[record for record in reader]
# Out:
# [{'header': {'identifier': {'_text': 'oai:www.e-rara.ch:1395833'},
#    'datestamp': {'_text': '2012-09-26T14:23:16Z'},
#    'setSpec': [{'_text': 'bes_1'},
#     {'_text': 'journal'},
#     {'_text': 'collections'},
#     {'_text': 'bernensia'},
#     {'_text': 'ch'},
#     {'_text': 'ch19'}]},
#   'metadata': {'{http://www.loc.gov/mods/v3}mods': {'_attrib': {'version': '3.6',
#      'xsi_schemaLocation': 'http://www.loc.gov/mods/v3 http://www.loc.gov/standards/mods/v3/mods-3-6.xsd'},
#     'mods_titleInfo': [{'mods_title': {'_text': 'Adressbuch der Stadt Bern'}},
#      {'_attrib': {'type': 'alternative'},
#       'mods_title': {'_text': 'Adressbuch der Stadt Bern einschliesslich Bümpliz, Köniz, Liebefeld...'}},
#      {'_attrib': {'type': 'alternative'},
#       'mods_title': {'_text': 'Adressbuch der Stadt Bern und Umgebung'}},
#      {'_attrib': {'type': 'alternative'},
#       'mods_title': {'_text': 'Adress-Kalender der Stadt Bern'}}],
#     'mods_typeOfResource': {'_text': 'text'},
#     'mods_genre': [{'_text': 'periodical', '_attrib': {'authority': 'marcgt'}},
#      {'_text': 'Text', '_attrib': {'authority': 'rdacontent'}},
#      {'_text': 'Zeitschrift', '_attrib': {'authority': 'gnd-content'}}],
#     'mods_originInfo': {'mods_place': [{'mods_placeTerm': {'_text': 'sz',
#         '_attrib': {'type': 'code', 'authority': 'marccountry'}}},
#       {'mods_placeTerm': {'_text': 'Bern', '_attrib': {'type': 'text'}}}],
#      'mods_publisher': {'_text': 'Hallwag'},
#      'mods_dateIssued': [{'_text': '1860',
#        '_attrib': {'encoding': 'w3cdtf', 'point': 'start', 'keyDate': 'yes'}},
#       {'_text': '1957', '_attrib': {'encoding': 'w3cdtf', 'point': 'end'}}],
#      'mods_issuance': {'_text': 'serial'},
#      'mods_frequency': [{'_text': 'Jährlich'},
#       {'_text': 'Completely irregular',
#        '_attrib': {'authority': 'marcfrequency'}}]},
#     'mods_language': {'mods_languageTerm': {'_text': 'ger',
#       '_attrib': {'authority': 'iso639-2b', 'type': 'code'}}},
#     'mods_physicalDescription': {'mods_form': [{'_text': 'print',
#        '_attrib': {'authority': 'marcform'}},
#       {'_text': 'electronic resource',
#        '_attrib': {'authority': 'marccategory'}},
#       {'_text': 'remote', '_attrib': {'authority': 'marcsmd'}},
#       {'_text': 'ohne Hilfsmittel zu benutzen',
#        '_attrib': {'type': 'media', 'authority': 'rdamedia'}},
#       {'_text': 'Computermedien',
#        '_attrib': {'type': 'media', 'authority': 'rdamedia'}},
#       {'_text': 'Band',
#        '_attrib': {'type': 'carrier', 'authority': 'rdacarrier'}},
#       {'_text': 'Online-Ressource',
#        '_attrib': {'type': 'carrier', 'authority': 'rdacarrier'}}],
#      'mods_extent': {'_text': '35 cm'}},
#     'mods_note': [{'_text': '1860 - Jg. 75(1957)',
#       '_attrib': {'type': 'date/sequential designation'}},
#      {'_text': 'Mit Stadtplan (zuerst eingeklebt, später als lose Beilage)'}],
#     'mods_classification': {'_text': '910',
#      '_attrib': {'authority': 'ddc', 'edition': '15'}},
#     'mods_identifier': {'_text': '10.3931/e-rara-4614',
#      '_attrib': {'type': 'doi'}},
#     'mods_relatedItem': [{'_attrib': {'type': 'constituent',
#        'otherType': '1871-1938;1946-1950:',
#        'displayLabel': '1871-1938;1946-1950:'},
#       'mods_titleInfo': {'mods_title': {'_text': 'Stadtplan aus Adressbuch'}}},
#      {'_attrib': {'type': 'constituent',
#        'otherType': '1882:',
#        'displayLabel': '1882:'},
#       'mods_titleInfo': {'mods_title': {'_text': 'Adressbuch der Stadt Bern: Die Häuser-Nummerierung in Bern'}}},
#      {'_attrib': {'type': 'constituent',
#        'otherType': '1939-1945:',
#        'displayLabel': '1939-1945:'},
#       'mods_titleInfo': {'mods_title': {'_text': 'Plan der Stadt Bern mit den umliegenden Gemeinden'}}},
#      {'_attrib': {'type': 'constituent',
#        'otherType': '1951-1972:',
#        'displayLabel': '1951-1972:'},
#       'mods_titleInfo': {'mods_title': {'_text': 'Stadtplan von Bern und Umgebung'}}},
#      {'_attrib': {'type': 'constituent',
#        'otherType': '1972-1980:',
#        'displayLabel': '1972-1980:'},
#       'mods_titleInfo': {'mods_title': {'_text': 'Stadtplan Bern'}}},
#      {'_attrib': {'type': 'constituent',
#        'otherType': '1980-:',
#        'displayLabel': '1980-:'},
#       'mods_titleInfo': {'mods_title': {'_text': 'Bern'}}},
#      {'_attrib': {'type': 'preceding'},
#       'mods_titleInfo': {'mods_title': {'_text': 'Hand- und Adressbuch der Bundesstadt Bern'}},
#       'mods_identifier': {'_text': '003065432', '_attrib': {'type': 'local'}}},
#      {'_attrib': {'type': 'succeeding'},
#       'mods_titleInfo': {'mods_title': {'_text': 'Berner Adressbuch'}}}],
#     'mods_location': [{'mods_physicalLocation': {'_text': 'A125 Jg.1877 ; 1886/87 ; 1897/98 ; 33(1905/06) ; 38(1915/16) ; 44(1925) ; 55(1936) ; 64(1946) ; 68(1950) ; 70(1952) ; 82(1964) ; 92(1974)'},
#       'mods_shelfLocator': {'_text': 'UBW Lexika BE 1'}},
#      {'mods_physicalLocation': {'_text': 'B400 1861, 1866 ; 1868/69 ; 1875 ; 1879 ; 1883/84 ; 1886/87 , 1888/89 ; 1891/92-Jg. 75(1957)'},
#       'mods_shelfLocator': {'_text': 'BeZ Hz V 17'}},
#      {'mods_physicalLocation': {'_text': 'B429 1904/05-1957'},
#       'mods_shelfLocator': {'_text': 'MfK Zbeah-00'}},
#      {'mods_physicalLocation': {'_text': 'B440 Siehe Einzelbände'},
#       'mods_shelfLocator': {'_text': '-'}},
#      {'mods_physicalLocation': {'_text': 'A100 Ausg. 36(1918) ; 38(1920) - 39(1921)'},
#       'mods_shelfLocator': {'_text': 'On 547'}},
#      {'mods_physicalLocation': {'_text': 'BFREE -'},
#       'mods_shelfLocator': {'_text': '-'}},
#      {'mods_url': {'_text': 'http://dx.doi.org/10.3931/e-rara-4614',
#        '_attrib': {'displayLabel': 'electronic resource',
#         'usage': 'primary display',
#         'note': 'Digitalisat in e-rara'}}}],
#     'mods_accessCondition': {'_text': 'pdm',
#      '_attrib': {'type': 'use and reproduction',
#       'xlink_href': 'https://creativecommons.org/publicdomain/mark/1.0',
#       'displayLabel': 'Public Domain Mark'}},
#     'mods_extension': {'vl_originInfo': {'_attrib': {'displayLabel': 'dc'},
#       'mods_dateCreated': [{'_text': '1860',
#         '_attrib': {'encoding': 'w3cdtf', 'point': 'start'}},
#        {'_text': '1957', '_attrib': {'encoding': 'w3cdtf', 'point': 'end'}}]},
#      '{http://visuallibrary.net/vlz/1.0/}info': {'_attrib': {'version': '2'}}},
#     'mods_recordInfo': {'mods_descriptionStandard': {'_text': 'kids'},
#      'mods_recordContentSource': {'_text': 'SzZuIDS BS/BE',
#       '_attrib': {'authority': 'marcorg'}},
#      'mods_recordCreationDate': {'_text': '851101',
#       '_attrib': {'encoding': 'marc'}},
#      'mods_recordChangeDate': {'_text': '20200827154300.0',
#       '_attrib': {'encoding': 'iso8601'}},
#      'mods_recordOrigin': {'_text': 'Converted from MARCXML to MODS version 3.6 using MARC21slim2MODS3-6.xsl\n\t\t\t\t(Revision 1.119 2018/06/21)'},
#      'mods_languageOfCataloging': {'mods_languageTerm': {'_text': 'ger',
#        '_attrib': {'authority': 'iso639-2b', 'type': 'code'}}},
#      'mods_recordIdentifier': {'_text': '99116914771105511',
#       '_attrib': {'source': 'bes_1'}}}}}}]

# %% [markdown]
# When you are heading for some information in the `metadata` section of the record, the qualifying string has to be adapted to `'{http://www.loc.gov/mods/v3}mods'`.

# %%
reader = OAIRecordReader(oai, metadata_prefix='mods', set_spec='bernensia', max_records=1)
for record in reader:
    print(record.header.identifier._text)
    print('---')
    print(record.metadata['{http://www.loc.gov/mods/v3}mods'].mods_titleInfo)
    print('---')
    print(record.metadata['{http://www.loc.gov/mods/v3}mods'].mods_titleInfo[0].mods_title._text)
    print(record.metadata['{http://www.loc.gov/mods/v3}mods'].mods_titleInfo[1].mods_title._text)
    print(record.metadata['{http://www.loc.gov/mods/v3}mods'].mods_titleInfo[2].mods_title._text)
    print(record.metadata['{http://www.loc.gov/mods/v3}mods'].mods_titleInfo[3].mods_title._text)
    print('---')
    print(record.metadata['{http://www.loc.gov/mods/v3}mods'].mods_titleInfo[3]._attrib.type)
# Out:
# oai:www.e-rara.ch:1395833
# ---
# [{'mods_title': {'_text': 'Adressbuch der Stadt Bern'}}, {'_attrib': {'type': 'alternative'}, 'mods_title': {'_text': 'Adressbuch der Stadt Bern einschliesslich Bümpliz, Köniz, Liebefeld...'}}, {'_attrib': {'type': 'alternative'}, 'mods_title': {'_text': 'Adressbuch der Stadt Bern und Umgebung'}}, {'_attrib': {'type': 'alternative'}, 'mods_title': {'_text': 'Adress-Kalender der Stadt Bern'}}]
# ---
# Adressbuch der Stadt Bern
# Adressbuch der Stadt Bern einschliesslich Bümpliz, Köniz, Liebefeld...
# Adressbuch der Stadt Bern und Umgebung
# Adress-Kalender der Stadt Bern
# ---
# alternative

# %% [markdown]
# Because drilling down the *navigable dictionary* path can lead to long and complicated commands - which might not be very clear, either - there is a catchier way to do so with the `get` command applied on the records.
# And: There is **no issue anymore with single values versus lists and qualifying strings**. Just putting the terms together as a list of `get` parameters!
#
# Note that in the case of more than one retrieved element a result list (in squared brackets) will be created.

# %%
reader = OAIRecordReader(oai, metadata_prefix='mods', set_spec='bernensia', max_records=1)
for record in reader:
    print(record.get(['header', 'identifier', '_text']))
    print('---')
    print(record.get(['metadata', '{http://www.loc.gov/mods/v3}mods', 'mods_titleInfo', 'mods_title', '_text']))
    print('---')
    print(record.get(['metadata', '{http://www.loc.gov/mods/v3}mods', 'mods_titleInfo', '_attrib', 'type']))
# Out:
# oai:www.e-rara.ch:1395833
# ---
# ['Adressbuch der Stadt Bern', 'Adressbuch der Stadt Bern einschliesslich Bümpliz, Köniz, Liebefeld...', 'Adressbuch der Stadt Bern und Umgebung', 'Adress-Kalender der Stadt Bern']
# ---
# [None, 'alternative', 'alternative', 'alternative']

# %% [markdown]
# This also works with the shorter form of for-loops. But mind that it delivers a nested - or 'doubled' - list, if there are the same elements several times, like `dc_identifier` here.

# %%
reader = OAIRecordReader(oai, set_spec='bernensia', metadata_prefix='oai_dc', max_records=1)

[record.get(['metadata', '{http://www.openarchives.org/OAI/2.0/oai_dc/}dc', 'dc_identifier', '_text']) \
            for record in reader]                          # '\' indicates that command proceeds on the next line
# Out:
# [['doi:10.3931/e-rara-4614',
#   'https://www.e-rara.ch/bes_1/doi/10.3931/e-rara-4614',
#   'system:99116914771105511']]

# %% [markdown]
# Now, it's really easy to access whatever metadata content you like.
#
# For instance, you might be interested in **all responsible persons and bodies**, their role, and GND identifiers...

# %%
# First looking at the 'mods_name' section of one record to get an overview of its structure
reader = OAIRecordReader(oai, metadata_prefix='mods', set_spec='bernensia', max_records=2)

[record.get(['metadata', '{http://www.loc.gov/mods/v3}mods', 'mods_name']) for record in reader]
# Out:
# [None,
#  {'_attrib': {'type': 'personal',
#    'usage': 'primary',
#    'authority': 'gnd',
#    'authorityURI': 'http://d-nb.info/gnd/',
#    'valueURI': 'http://d-nb.info/gnd/127809651,'},
#   'mods_nameIdentifier': {'_text': '(DE-588)127809651,'},
#   'mods_namePart': [{'_text': 'Raemy, Alfred de'},
#    {'_text': '1825-1909', '_attrib': {'type': 'date'}}],
#   'mods_role': [{'mods_roleTerm': {'_text': 'Verfasser',
#      '_attrib': {'type': 'text'}}},
#    {'mods_roleTerm': {'_text': 'aut',
#      '_attrib': {'authority': 'marcrelator', 'type': 'code'}}}]}]

# %%
# Selecting the 'mods_name' sub-elements of interest of ten records
reader = OAIRecordReader(oai, set_spec='bernensia', metadata_prefix='mods', max_records=10)
for record in reader:
    print(record.get(['metadata', '{http://www.loc.gov/mods/v3}mods', 'mods_name', 'mods_namePart', '_text']))
    print(record.get(['metadata', '{http://www.loc.gov/mods/v3}mods', 'mods_name', '_attrib', 'valueURI']))
    print(record.get(['metadata', '{http://www.loc.gov/mods/v3}mods', 'mods_name', 'mods_role', 'mods_roleTerm', \
                      '_text']))
    print('---')
# Out:
# None
# None
# None
# ---
# ['Raemy, Alfred de', '1825-1909']
# http://d-nb.info/gnd/127809651,
# ['Verfasser', 'aut']
# ---
# Sommerlatt, Christian Vollrath von
# http://d-nb.info/gnd/100559921
# None
# ---
# Typographische Societäts-Buchhandlung (Bern)
# http://d-nb.info/gnd/1086438582,
# ['Drucker', 'prt']
# ---
# Messerli, Johann Ch.
# None
# None
# ---
# None
# None
# None
# ---
# Sterchi, Jakob
# None
# None
# ---
# ['Jenni, Christian Albrecht', '1786-1861']
# http://d-nb.info/gnd/1037555503
# ['Herausgeber', 'edt']
# ---
# None
# None
# None
# ---
# ['Tscharner, Friedrich', ['Haller, Ludwig Albrecht', '1773-1837'], 'Stadtbibliothek Bern']
# [None, 'http://d-nb.info/gnd/1037511646', 'http://d-nb.info/gnd/508313-8']
# [None, ['Drucker', 'prt'], None]
# ---

# %% [markdown]
# ### 1.3 Retrieve the licences

# %% [markdown]
# E-rara's documents are published under different licences. To get an overview you might look at the [Terms of Use](https://www.e-rara.ch/wiki/termsOfUse?lang=en). Here's a short how-to to get the rights information out of the OAI metadata.
#
# First, let's check the rights information in the *Dublin Core* format. Often 'pdm' for *Public Domain Mark* will be delivered.

# %%
reader = OAIRecordReader(oai, set_spec='ch20', metadata_prefix='oai_dc', max_records=10)
[record.metadata['{http://www.openarchives.org/OAI/2.0/oai_dc/}dc'].dc_rights._text \
  for record in reader]
# Out:
# ['pdm', 'pdm', 'pdm', 'pdm', 'pdm', 'pdm', 'pdm', 'pdm', 'pdm', 'pdm']

# %% [markdown]
# Grabbing the rights information of the *MODS* format might be an alternative.

# %%
reader = OAIRecordReader(oai, metadata_prefix='mods', set_spec='ch20', max_records=5)
for record in reader:
    print(record.header.identifier._text) 
    print(record.get(['metadata', '{http://www.loc.gov/mods/v3}mods', 'mods_accessCondition', '_attrib', \
                      'type']))
    print(record.get(['metadata', '{http://www.loc.gov/mods/v3}mods', 'mods_accessCondition', '_attrib', \
                      'displayLabel']))
    print('---')
# Out:
# oai:www.e-rara.ch:1423055
# use and reproduction
# Public Domain Mark
# ---
# oai:www.e-rara.ch:2554533
# use and reproduction
# Public Domain Mark
# ---
# oai:www.e-rara.ch:3869077
# use and reproduction
# Public Domain Mark
# ---
# oai:www.e-rara.ch:3870000
# use and reproduction
# Public Domain Mark
# ---
# oai:www.e-rara.ch:6286695
# use and reproduction
# Public Domain Mark
# ---

# %% [markdown]
# To get a better view and a more usable format for further work, you can write the rights into a dataframe, too.

# %%
reader = OAIRecordReader(oai, metadata_prefix='mods', set_spec='ch20', max_records=5)
identifier = []
dc_rights = []                          

for record in reader:
    identifier.append(record.header.identifier._text)
    dc_rights.append(record.get(['metadata', '{http://www.loc.gov/mods/v3}mods', 'mods_accessCondition', \
                                 '_attrib', 'displayLabel']))

dic = {'ID': identifier, 'rights': dc_rights} 
df = pd.DataFrame(dic)  
df
# Out:
#                           ID              rights
# 0  oai:www.e-rara.ch:1423055  Public Domain Mark
# 1  oai:www.e-rara.ch:2554533  Public Domain Mark
# 2  oai:www.e-rara.ch:3869077  Public Domain Mark
# 3  oai:www.e-rara.ch:3870000  Public Domain Mark
# 4  oai:www.e-rara.ch:6286695  Public Domain Mark

# %% [markdown]
# Also, you easily can get an overview over the rights of a whole OAI set with the `Counter` function from the `collections` library. Doing this you can choose the maximum records via the known parameter.

# %%
import collections
reader = OAIRecordReader(oai, set_spec='ch20', metadata_prefix='oai_dc', max_records=100)

dc_rights = [record.metadata['{http://www.openarchives.org/OAI/2.0/oai_dc/}dc'].dc_rights._text \
  for record in reader]
counter = collections.Counter(dc_rights)
counter
# Out:
# Counter({'pdm': 100})

# %% [markdown]
# ### 1.4 Save  and recover complex metadata structures

# %% [markdown]
# Before any data will be downloaded, let's build a common folder named `data` aside our working directory to store any data into.

# %%
print(os.getcwd())                                # print current working directory
# Out:
# C:\Users\kwoit\Documents\GitHub\e-rara-access

# %% [markdown]
# In case you might change your directory you can easily do this with `os.chdir` or `os.chdir(os.pardir)`.  While `os.chdir()` changes the working directory to a subdirectory, `os.chdir(os.pardir)` will change it to the parent directory. Just uncomment (and maybe multiply) the commands you need.

# %%
#os.chdir(os.pardir)                              # change to parent directory
#os.chdir('...')                                  # change to '...' subdirectory
#print(os.getcwd())

# %%
os.makedirs('data', exist_ok=True)                # make new folder 'data'
os.chdir('data')                                  # change to 'data' folder
print(os.getcwd())
# Out:
# C:\Users\kwoit\Documents\GitHub\e-rara-access\data

# %% [markdown]
# To **download a whole bunch of metadata items** in nested formats like *MODS*, the 'JSONWriter' from Polymatheia is very helpful.
# It creates a complex folder structure and JSON files to reproduce the structured metadata. And with 'JSONReader' one can easily recover the metadata set.

# %%
from polymatheia.data.writer import JSONWriter     # also available: CSVReader (for flat data), XMLReader and Writer
from polymatheia.data.reader import JSONReader

# %% [markdown]
# 'JSONWriter' takes two parameters:
# - The first is the name of the directory into which the data should be stored.
# - The second is the dot-notated path (via its `header.identifier`) used to access the item's metadata.
#
# For more clarity, these are the contents of `header.identifier` for the first ten Bernensia records we will refer to:

# %%
reader = OAIRecordReader(oai, set_spec='bernensia', metadata_prefix='mods', max_records=10)
for record in reader:
    print(record.header.identifier._text)
# Out:
# oai:www.e-rara.ch:1395833
# oai:www.e-rara.ch:1396731
# oai:www.e-rara.ch:1397203
# oai:www.e-rara.ch:1757425
# oai:www.e-rara.ch:1757509
# oai:www.e-rara.ch:1757592
# oai:www.e-rara.ch:1757931
# oai:www.e-rara.ch:1758267
# oai:www.e-rara.ch:2069554
# oai:www.e-rara.ch:4709578

# %%
# Download and save the first ten Bernensia records from MODS format
# 'poly_metadata' = directory to store into
reader = OAIRecordReader(oai, set_spec='bernensia', metadata_prefix='mods', max_records=10)
writer = JSONWriter('poly_metadata', 'header.identifier._text')
writer.write(reader)

# %%
# Recover the first ten Bernensia records from local disk
reader = JSONReader('poly_metadata')
[record for record in reader]
# Out:
# [{'header': {'identifier': {'_text': 'oai:www.e-rara.ch:1757592'},
#    'datestamp': {'_text': '2012-05-08T13:37:52Z'},
#    'setSpec': [{'_text': 'bes_1'},
#     {'_text': 'journal'},
#     {'_text': 'collections'},
#     {'_text': 'bernensia'},
#     {'_text': 'ch'},
#     {'_text': 'ch19'}]},
#   'metadata': {'{http://www.loc.gov/mods/v3}mods': {'_attrib': {'version': '3.6',
#      'xsi_schemaLocation': 'http://www.loc.gov/mods/v3 http://www.loc.gov/standards/mods/v3/mods-3-6.xsd'},
#     'mods_titleInfo': {'mods_title': {'_text': 'Hand- und Adressbuch der Bundesstadt Bern'},
#      'mods_subTitle': {'_text': 'Verzeichniss der Behörden, Angabe der Häuserbesitzer und Wohnungen, der Handels- und Gewerbstreibenden, der Gesellschaften und Vereine, Tarife und Verordnungen der Verkehrsanstalten u. dgl. m'}},
#     'mods_typeOfResource': {'_text': 'text'},
#     'mods_genre': [{'_text': 'periodical', '_attrib': {'authority': 'marcgt'}},
#      {'_text': 'Text', '_attrib': {'authority': 'rdacontent'}},
#      {'_text': 'Zeitschrift', '_attrib': {'authority': 'gnd-content'}}],
#     'mods_originInfo': {'mods_place': [{'mods_placeTerm': {'_text': 'sz',
#         '_attrib': {'type': 'code', 'authority': 'marccountry'}}},
#       {'mods_placeTerm': {'_text': 'Bern', '_attrib': {'type': 'text'}}}],
#      'mods_publisher': {'_text': 'Jent & Gassmann'},
#      'mods_dateIssued': {'_text': '1859',
#       '_attrib': {'encoding': 'w3cdtf', 'point': 'start', 'keyDate': 'yes'}},
#      'mods_issuance': {'_text': 'serial'},
#      'mods_frequency': {'_text': 'Completely irregular',
#       '_attrib': {'authority': 'marcfrequency'}}},
#     'mods_language': {'mods_languageTerm': {'_text': 'ger',
#       '_attrib': {'authority': 'iso639-2b', 'type': 'code'}}},
#     'mods_physicalDescription': {'mods_form': [{'_text': 'print',
#        '_attrib': {'authority': 'marcform'}},
#       {'_text': 'electronic resource',
#        '_attrib': {'authority': 'marccategory'}},
#       {'_text': 'remote', '_attrib': {'authority': 'marcsmd'}},
#       {'_text': 'ohne Hilfsmittel zu benutzen',
#        '_attrib': {'type': 'media', 'authority': 'rdamedia'}},
#       {'_text': 'Computermedien',
#        '_attrib': {'type': 'media', 'authority': 'rdamedia'}},
#       {'_text': 'Band',
#        '_attrib': {'type': 'carrier', 'authority': 'rdacarrier'}},
#       {'_text': 'Online-Ressource',
#        '_attrib': {'type': 'carrier', 'authority': 'rdacarrier'}}],
#      'mods_extent': {'_text': "8'"}},
#     'mods_note': {'_text': '1859',
#      '_attrib': {'type': 'date/sequential designation'}},
#     'mods_identifier': {'_text': '10.3931/e-rara-7083',
#      '_attrib': {'type': 'doi'}},
#     'mods_relatedItem': {'_attrib': {'type': 'succeeding'},
#      'mods_titleInfo': {'mods_title': {'_text': 'Adressbuch der Stadt Bern'}}},
#     'mods_location': [{'mods_physicalLocation': {'_text': 'A100 1859'},
#       'mods_shelfLocator': {'_text': 'VB G 224:7'}},
#      {'mods_physicalLocation': {'_text': 'B400 1859'},
#       'mods_shelfLocator': {'_text': 'BeZ Hz V 17'}},
#      {'mods_physicalLocation': {'_text': 'B434 1859'},
#       'mods_shelfLocator': {'_text': 'StAB A 843'}},
#      {'mods_url': {'_text': 'http://dx.doi.org/10.3931/e-rara-7083',
#        '_attrib': {'displayLabel': 'electronic resource',
#         'usage': 'primary display',
#         'note': 'Digitalisat in e-rara'}}}],
#     'mods_accessCondition': {'_text': 'pdm',
#      '_attrib': {'type': 'use and reproduction',
#       'xlink_href': 'https://creativecommons.org/publicdomain/mark/1.0',
#       'displayLabel': 'Public Domain Mark'}},
#     'mods_extension': {'vl_originInfo': {'_attrib': {'displayLabel': 'dc'},
#       'mods_dateCreated': {'_text': '1859',
#        '_attrib': {'encoding': 'w3cdtf', 'point': 'start'}}},
#      '{http://visuallibrary.net/vlz/1.0/}info': {'_attrib': {'version': '2'}}},
#     'mods_recordInfo': {'mods_descriptionStandard': {'_text': 'kids'},
#      'mods_recordContentSource': {'_text': 'SzZuIDS BS/BE A100',
#       '_attrib': {'authority': 'marcorg'}},
#      'mods_recordCreationDate': {'_text': '031105',
#       '_attrib': {'encoding': 'marc'}},
#      'mods_recordChangeDate': {'_text': '20191123124200.0',
#       '_attrib': {'encoding': 'iso8601'}},
#      'mods_recordOrigin': {'_text': 'Converted from MARCXML to MODS version 3.6 using MARC21slim2MODS3-6.xsl\n\t\t\t\t(Revision 1.119 2018/06/21)'},
#      'mods_recordIdentifier': {'_text': '99116927416005511',
#       '_attrib': {'source': 'bes_1'}}}}}},
#  {'header': {'identifier': {'_text': 'oai:www.e-rara.ch:1397203'},
#    'datestamp': {'_text': '2011-04-05T14:34:28Z'},
#    'setSpec': [{'_text': 'bes_1'},
#     {'_text': 'book'},
#     {'_text': 'collections'},
#     {'_text': 'bernensia'},
#     {'_text': 'ch'},
#     {'_text': 'ch19'}]},
#   'metadata': {'{http://www.loc.gov/mods/v3}mods': {'_attrib': {'version': '3.6',
#      'xsi_schemaLocation': 'http://www.loc.gov/mods/v3 http://www.loc.gov/standards/mods/v3/mods-3-6.xsd'},
#     'mods_titleInfo': {'mods_title': {'_text': 'Adressenbuch der Republik Bern'},
#      'mods_subTitle': {'_text': 'für Wissenschaft, Kunst, Handel und Gewerbe, sammt Beschreibung der Merkwürdigkeiten, öffentlichen Anstalten und sonstigen nützlichen Einrichtungen'}},
#     'mods_name': {'_attrib': {'type': 'personal',
#       'usage': 'primary',
#       'authority': 'gnd',
#       'authorityURI': 'http://d-nb.info/gnd/',
#       'valueURI': 'http://d-nb.info/gnd/100559921'},
#      'mods_nameIdentifier': {'_text': '(DE-588)100559921'},
#      'mods_namePart': {'_text': 'Sommerlatt, Christian Vollrath von'}},
#     'mods_typeOfResource': {'_text': 'text'},
#     'mods_genre': {'_text': 'Text', '_attrib': {'authority': 'rdacontent'}},
#     'mods_originInfo': {'mods_place': [{'mods_placeTerm': {'_text': 'sz',
#         '_attrib': {'type': 'code', 'authority': 'marccountry'}}},
#       {'mods_placeTerm': {'_text': 'Bern', '_attrib': {'type': 'text'}}}],
#      'mods_publisher': {'_text': 'C. A. Jenni'},
#      'mods_dateIssued': {'_text': '1836', '_attrib': {'keyDate': 'yes'}},
#      'mods_issuance': {'_text': 'single unit'}},
#     'mods_language': {'mods_languageTerm': {'_text': 'ger',
#       '_attrib': {'authority': 'iso639-2b', 'type': 'code'}}},
#     'mods_physicalDescription': {'mods_form': [{'_text': 'print',
#        '_attrib': {'authority': 'marcform'}},
#       {'_text': 'electronic resource',
#        '_attrib': {'authority': 'marccategory'}},
#       {'_text': 'remote', '_attrib': {'authority': 'marcsmd'}},
#       {'_text': 'Computermedien',
#        '_attrib': {'type': 'media', 'authority': 'rdamedia'}},
#       {'_text': 'ohne Hilfsmittel zu benutzen',
#        '_attrib': {'type': 'media', 'authority': 'rdamedia'}},
#       {'_text': 'Online-Ressource',
#        '_attrib': {'type': 'carrier', 'authority': 'rdacarrier'}},
#       {'_text': 'Band',
#        '_attrib': {'type': 'carrier', 'authority': 'rdacarrier'}}],
#      'mods_extent': {'_text': '2 Abt. in 1 Bd.'}},
#     'mods_tableOfContents': [{'_text': 'Abtheilung 1 : Hauptstadt Bern'},
#      {'_text': 'Abtheilung 2 : Kanton Bern'}],
#     'mods_note': [{'_text': 'Bearb. und hrsg. von C. v. Sommerlatt',
#       '_attrib': {'type': 'statement of responsibility', 'altRepGroup': '00'}},
#      {'_text': 'Beigebunden: Ergänzungsheft zu dem Adressbuch der Republik Bern von 1836. Erschienen im April 1839, Thun.'}],
#     'mods_identifier': {'_text': '10.3931/e-rara-4616',
#      '_attrib': {'type': 'doi'}},
#     'mods_location': [{'mods_physicalLocation': {'_text': 'B440 -'},
#       'mods_shelfLocator': {'_text': '-'}},
#      {'mods_physicalLocation': {'_text': 'B404'},
#       'mods_shelfLocator': {'_text': 'MUE H II 16'},
#       'mods_holdingSimple': {'mods_copyInformation': {'mods_itemIdentifier': {'_text': 'BM1050732'}}}},
#      {'mods_physicalLocation': {'_text': 'B400'},
#       'mods_shelfLocator': {'_text': 'BeM ZB H LIII 313'},
#       'mods_holdingSimple': {'mods_copyInformation': {'mods_itemIdentifier': {'_text': '000651992'}}}},
#      {'mods_physicalLocation': {'_text': 'A100'},
#       'mods_shelfLocator': {'_text': 'Falk 1308'},
#       'mods_holdingSimple': {'mods_copyInformation': {'mods_itemIdentifier': {'_text': 'DSVN3144250'}}}},
#      {'mods_physicalLocation': {'_text': 'B440'},
#       'mods_shelfLocator': {'_text': 'BBB D 3438'},
#       'mods_holdingSimple': {'mods_copyInformation': {'mods_itemIdentifier': {'_text': 'DSVN5472519'}}}},
#      {'mods_physicalLocation': {'_text': 'B434'},
#       'mods_shelfLocator': {'_text': 'StAB A 6760'},
#       'mods_holdingSimple': {'mods_copyInformation': {'mods_itemIdentifier': {'_text': 'DSVN6011047'}}}},
#      {'mods_physicalLocation': {'_text': 'B440'},
#       'mods_shelfLocator': {'_text': 'BBB B 6.3 : 1836'},
#       'mods_holdingSimple': {'mods_copyInformation': {'mods_itemIdentifier': {'_text': 'DSVN6644949'}}}},
#      {'mods_physicalLocation': {'_text': 'B440'},
#       'mods_shelfLocator': {'_text': 'BBB D 3358'},
#       'mods_holdingSimple': {'mods_copyInformation': {'mods_itemIdentifier': {'_text': 'DSVN6807373'}}}},
#      {'mods_url': {'_text': 'http://dx.doi.org/10.3931/e-rara-4616',
#        '_attrib': {'displayLabel': 'electronic resource',
#         'usage': 'primary display',
#         'note': 'Digitalisat in e-rara'}}}],
#     'mods_accessCondition': {'_text': 'pdm',
#      '_attrib': {'type': 'use and reproduction',
#       'xlink_href': 'https://creativecommons.org/publicdomain/mark/1.0',
#       'displayLabel': 'Public Domain Mark'}},
#     'mods_extension': {'vl_originInfo': {'_attrib': {'displayLabel': 'dc'},
#       'mods_dateCreated': {'_text': '1836',
#        '_attrib': {'encoding': 'w3cdtf', 'point': 'start'}}},
#      '{http://visuallibrary.net/vlz/1.0/}info': {'_attrib': {'version': '2'}}},
#     'mods_recordInfo': {'mods_descriptionStandard': {'_text': 'kids'},
#      'mods_recordContentSource': {'_text': 'SzZuIDS BS/BE B400',
#       '_attrib': {'authority': 'marcorg'}},
#      'mods_recordCreationDate': {'_text': '051104',
#       '_attrib': {'encoding': 'marc'}},
#      'mods_recordChangeDate': {'_text': '20170606090500.0',
#       '_attrib': {'encoding': 'iso8601'}},
#      'mods_recordOrigin': {'_text': 'Converted from MARCXML to MODS version 3.6 using MARC21slim2MODS3-6.xsl\n\t\t\t\t(Revision 1.119 2018/06/21)'},
#      'mods_recordIdentifier': {'_text': '99116872618805511',
#       '_attrib': {'source': 'bes_1'}}}}}},
#  {'header': {'identifier': {'_text': 'oai:www.e-rara.ch:4709578'},
#    'datestamp': {'_text': '2013-05-14T14:21:11Z'},
#    'setSpec': [{'_text': 'bes_1'},
#     {'_text': 'book'},
#     {'_text': 'collections'},
#     {'_text': 'bernensia'},
#     {'_text': 'ch'},
#     {'_text': 'ch19'}]},
#   'metadata': {'{http://www.loc.gov/mods/v3}mods': {'_attrib': {'version': '3.6',
#      'xsi_schemaLocation': 'http://www.loc.gov/mods/v3 http://www.loc.gov/standards/mods/v3/mods-3-6.xsd'},
#     'mods_titleInfo': [{'mods_title': {'_text': 'Verzeichniss aller auf der Stadt-Bibliothek in Bern vorhandenen gedruckten Werke'}},
#      {'_attrib': {'type': 'alternative'},
#       'mods_title': {'_text': 'Verzeichnis aller auf der Stadtbibliothek in Bern vorhandenen gedruckten Werke'}},
#      {'_attrib': {'type': 'alternative', 'displayLabel': 'Supplemente'},
#       'mods_title': {'_text': '[Erstes - Drittes] Supplement zum Catalog der Stadt-Bibliothek in Bern'}}],
#     'mods_name': [{'_attrib': {'type': 'personal'},
#       'mods_namePart': {'_text': 'Tscharner, Friedrich'}},
#      {'_attrib': {'type': 'personal',
#        'authority': 'gnd',
#        'authorityURI': 'http://d-nb.info/gnd/',
#        'valueURI': 'http://d-nb.info/gnd/1037511646'},
#       'mods_nameIdentifier': {'_text': '(DE-588)1037511646'},
#       'mods_namePart': [{'_text': 'Haller, Ludwig Albrecht'},
#        {'_text': '1773-1837', '_attrib': {'type': 'date'}}],
#       'mods_role': [{'mods_roleTerm': {'_text': 'Drucker',
#          '_attrib': {'type': 'text'}}},
#        {'mods_roleTerm': {'_text': 'prt',
#          '_attrib': {'authority': 'marcrelator', 'type': 'code'}}}]},
#      {'_attrib': {'type': 'corporate',
#        'authority': 'gnd',
#        'authorityURI': 'http://d-nb.info/gnd/',
#        'valueURI': 'http://d-nb.info/gnd/508313-8'},
#       'mods_nameIdentifier': {'_text': '(DE-588)508313-8'},
#       'mods_namePart': {'_text': 'Stadtbibliothek Bern'}}],
#     'mods_typeOfResource': {'_text': 'text'},
#     'mods_originInfo': {'mods_place': [{'mods_placeTerm': {'_text': 'sz',
#         '_attrib': {'type': 'code', 'authority': 'marccountry'}}},
#       {'mods_placeTerm': {'_text': 'Bern', '_attrib': {'type': 'text'}}}],
#      'mods_publisher': {'_text': 'gedruckt bey Ludwig Albrecht Haller'},
#      'mods_dateIssued': [{'_text': '1811-1856'},
#       {'_text': '1811',
#        '_attrib': {'encoding': 'w3cdtf', 'point': 'start', 'keyDate': 'yes'}},
#       {'_text': '1856', '_attrib': {'encoding': 'w3cdtf', 'point': 'end'}}],
#      'mods_issuance': {'_text': 'multipart monograph'}},
#     'mods_language': {'mods_languageTerm': {'_text': 'ger',
#       '_attrib': {'authority': 'iso639-2b', 'type': 'code'}}},
#     'mods_physicalDescription': {'mods_form': [{'_text': 'print',
#        '_attrib': {'authority': 'marcform'}},
#       {'_text': 'electronic resource',
#        '_attrib': {'authority': 'marccategory'}},
#       {'_text': 'remote', '_attrib': {'authority': 'marcsmd'}}],
#      'mods_extent': {'_text': '3 Theile, 3 Supplemente ; 20 cm (8°)'}},
#     'mods_note': [{'_text': 'Erster alphabetischer Katalog der damaligen Stadtbibliothek, verfasst vom Oberbibliothekar F. Tscharner'},
#      {'_text': 'Theil 1 (1811): XLVIII, 470 S.; Theil 2 (1811): 508 S.; Theil 3 (1811): 462 S.; Suppl. (1839): XXII, 287 S.; Suppl. 2 (1847): 224 S.; Suppl. 3 (1856): 390 S.'},
#      {'_text': 'Betrifft die Handschrift Cod. 757.I der Burgerbibliothek Bern (S. 212).'}],
#     'mods_subject': {'mods_geographic': {'_text': 'Bern',
#       '_attrib': {'authority': 'gnd',
#        'authorityURI': 'http://d-nb.info/gnd/',
#        'valueURI': 'http://d-nb.info/gnd/4005762-8'}}},
#     'mods_identifier': {'_text': '10.3931/e-rara-15158',
#      '_attrib': {'type': 'doi'}},
#     'mods_location': [{'mods_url': {'_text': 'http://dx.doi.org/10.3931/e-rara-15158',
#        '_attrib': {'displayLabel': 'electronic resource',
#         'usage': 'primary display',
#         'note': 'Digitalisat in e-rara'}}},
#      {'mods_physicalLocation': {'_text': 'B400',
#        '_attrib': {'displayLabel': 'Bern UB Speichermagazin',
#         'authority': 'local library code'}},
#       'mods_holdingSimple': {'mods_copyInformation': [{'mods_subLocation': {'_text': 'Sektor F3'},
#          'mods_shelfLocator': [{'_text': '-'},
#           {'_text': 'BeM ZB AL 239 a : 3'}],
#          'mods_itemIdentifier': {'_text': 'BM1137757'}},
#         {'mods_subLocation': {'_text': 'Sektor F3'},
#          'mods_shelfLocator': {'_text': 'BeM ZB AL 239 a : 2'},
#          'mods_itemIdentifier': {'_text': 'BM1137756'}},
#         {'mods_subLocation': {'_text': 'Sektor F3'},
#          'mods_shelfLocator': {'_text': 'BeM ZB AL 239 a : 1'},
#          'mods_itemIdentifier': {'_text': 'BM1137755'}},
#         {'mods_subLocation': {'_text': 'Sektor F3'},
#          'mods_shelfLocator': {'_text': 'BeM ZB AL 239 b : 1'},
#          'mods_itemIdentifier': {'_text': 'BM1137758'}},
#         {'mods_subLocation': {'_text': 'Sektor F3'},
#          'mods_shelfLocator': {'_text': 'BeM ZB AL 239 b : 2'},
#          'mods_itemIdentifier': {'_text': 'BM1137759'}},
#         {'mods_subLocation': {'_text': 'Sektor F3'},
#          'mods_shelfLocator': {'_text': 'BeM ZB AL 239 b : 3'},
#          'mods_itemIdentifier': {'_text': 'BM1137760'}}]}},
#      {'mods_physicalLocation': {'_text': 'B404',
#        '_attrib': {'displayLabel': 'Bern UB Münstergasse',
#         'authority': 'local library code'}},
#       'mods_holdingSimple': {'mods_copyInformation': [{'mods_subLocation': {'_text': 'Magazin'},
#          'mods_shelfLocator': [{'_text': '-'}, {'_text': 'MUE Thun 868 : 1'}],
#          'mods_itemIdentifier': {'_text': 'BM1849212'}},
#         {'mods_subLocation': {'_text': 'Magazin'},
#          'mods_shelfLocator': {'_text': 'MUE Thun 868 : 2'},
#          'mods_itemIdentifier': {'_text': 'BM1849213'}},
#         {'mods_subLocation': {'_text': 'Magazin'},
#          'mods_shelfLocator': {'_text': 'MUE Thun 868 : 3'},
#          'mods_itemIdentifier': {'_text': 'BM1849214'}},
#         {'mods_subLocation': {'_text': 'Magazin'},
#          'mods_shelfLocator': {'_text': 'MUE Rar alt 502 : 1'},
#          'mods_itemIdentifier': {'_text': 'BM1560538'}}]}}],
#     'mods_accessCondition': {'_text': 'pdm',
#      '_attrib': {'type': 'use and reproduction',
#       'xlink_href': 'https://creativecommons.org/publicdomain/mark/1.0',
#       'displayLabel': 'Public Domain Mark'}},
#     'mods_extension': {'vl_originInfo': {'_attrib': {'displayLabel': 'dc'},
#       'mods_dateCreated': [{'_text': '1811',
#         '_attrib': {'encoding': 'w3cdtf', 'point': 'start'}},
#        {'_text': '1856', '_attrib': {'encoding': 'w3cdtf', 'point': 'end'}}]},
#      '{http://visuallibrary.net/vlz/1.0/}info': {'_attrib': {'version': '2'}}},
#     'mods_recordInfo': {'mods_descriptionStandard': {'_text': 'kids'},
#      'mods_recordContentSource': {'_text': 'SzZuIDS BS/BE A100',
#       '_attrib': {'authority': 'marcorg'}},
#      'mods_recordCreationDate': {'_text': '030219',
#       '_attrib': {'encoding': 'marc'}},
#      'mods_recordChangeDate': {'_text': '20201224025247.0',
#       '_attrib': {'encoding': 'iso8601'}},
#      'mods_recordIdentifier': {'_text': '99116836054205511',
#       '_attrib': {'source': 'bes_1'}},
#      'mods_recordOrigin': {'_text': 'Converted from MARCXML to MODS version 3.6 using MARC21slim2MODS3-6.xsl\n\t\t\t\t(Revision 1.119 2018/06/21)'}}}}},
#  {'header': {'identifier': {'_text': 'oai:www.e-rara.ch:1758267'},
#    'datestamp': {'_text': '2012-05-08T13:38:33Z'},
#    'setSpec': [{'_text': 'bes_1'},
#     {'_text': 'book'},
#     {'_text': 'collections'},
#     {'_text': 'bernensia'},
#     {'_text': 'ch'},
#     {'_text': 'ch19'}]},
#   'metadata': {'{http://www.loc.gov/mods/v3}mods': {'_attrib': {'version': '3.6',
#      'xsi_schemaLocation': 'http://www.loc.gov/mods/v3 http://www.loc.gov/standards/mods/v3/mods-3-6.xsd'},
#     'mods_titleInfo': [{'mods_title': {'_text': 'Sammlung der Grabschriften der gegenwärtigen Bernischen Gottesäcker Monbijou, Rosengarten und Klösterlein'}},
#      {'_attrib': {'type': 'alternative'},
#       'mods_title': {'_text': 'Fortsetzung der Sammlung der Grabschriften der ... Gottesäcker Monbijou und Rosengarten'}}],
#     'mods_name': {'_attrib': {'type': 'personal',
#       'authority': 'gnd',
#       'authorityURI': 'http://d-nb.info/gnd/',
#       'valueURI': 'http://d-nb.info/gnd/1037555503'},
#      'mods_nameIdentifier': {'_text': '(DE-588)1037555503'},
#      'mods_namePart': [{'_text': 'Jenni, Christian Albrecht'},
#       {'_text': '1786-1861', '_attrib': {'type': 'date'}}],
#      'mods_role': [{'mods_roleTerm': {'_text': 'Herausgeber',
#         '_attrib': {'type': 'text'}}},
#       {'mods_roleTerm': {'_text': 'edt',
#         '_attrib': {'authority': 'marcrelator', 'type': 'code'}}}]},
#     'mods_typeOfResource': {'_text': 'text'},
#     'mods_originInfo': {'mods_place': [{'mods_placeTerm': {'_text': 'sz',
#         '_attrib': {'type': 'code', 'authority': 'marccountry'}}},
#       {'mods_placeTerm': {'_text': 'Bern', '_attrib': {'type': 'text'}}}],
#      'mods_publisher': [{'_text': '[Verlag nicht ermittelbar]'},
#       {'_text': 'C.A. Jenni'},
#       {'_text': 'gedruckt bei Ulr. Nicl. Schönauer'}],
#      'mods_dateIssued': [{'_text': '1821-1822'},
#       {'_text': '1821',
#        '_attrib': {'encoding': 'w3cdtf', 'point': 'start', 'keyDate': 'yes'}},
#       {'_text': '1822', '_attrib': {'encoding': 'w3cdtf', 'point': 'end'}}],
#      'mods_issuance': {'_text': 'multipart monograph'}},
#     'mods_language': {'mods_languageTerm': {'_text': 'ger',
#       '_attrib': {'authority': 'iso639-2b', 'type': 'code'}}},
#     'mods_physicalDescription': {'mods_form': [{'_text': 'print',
#        '_attrib': {'authority': 'marcform'}},
#       {'_text': 'electronic resource',
#        '_attrib': {'authority': 'marccategory'}},
#       {'_text': 'remote', '_attrib': {'authority': 'marcsmd'}}],
#      'mods_extent': {'_text': '2 Bände (104 Seiten, 1 ungezähltes Blatt, 36 Seiten) ; 8°'}},
#     'mods_note': [{'_text': 'Hrsg. von Christian Albrecht Jenni ; Fortsetzung der Sammlung der Grabschriften der ... Gottesäcker Monbijou und Rosengarten',
#       '_attrib': {'type': 'statement of responsibility', 'altRepGroup': '00'}},
#      {'_text': 'Herausgeber am Ende des Vorworts von Band 2: "C. A. Jenni"'}],
#     'mods_identifier': {'_text': '10.3931/e-rara-7086',
#      '_attrib': {'type': 'doi'}},
#     'mods_relatedItem': {'_attrib': {'type': 'constituent'},
#      'mods_titleInfo': {'mods_title': {'_text': 'Fortsetzung der Sammlung der Grabschriften der ... Gottesäcker Monbijou und Rosengarten'}}},
#     'mods_location': [{'mods_url': {'_text': 'http://dx.doi.org/10.3931/e-rara-7086',
#        '_attrib': {'displayLabel': 'electronic resource',
#         'usage': 'primary display',
#         'note': 'Digitalisat in e-rara'}}},
#      {'mods_physicalLocation': {'_text': 'B404',
#        '_attrib': {'displayLabel': 'Bern UB Münstergasse',
#         'authority': 'local library code'}},
#       'mods_holdingSimple': {'mods_copyInformation': [{'mods_subLocation': {'_text': 'Magazin'},
#          'mods_shelfLocator': [{'_text': '-'},
#           {'_text': 'MUE H VIII 162 : 1'}],
#          'mods_itemIdentifier': {'_text': 'BM1049628'}},
#         {'mods_subLocation': {'_text': 'Magazin'},
#          'mods_shelfLocator': {'_text': 'MUE Laut 829 : 15'},
#          'mods_itemIdentifier': {'_text': 'DSVN1953205'}},
#         {'mods_subLocation': {'_text': 'Magazin'},
#          'mods_shelfLocator': {'_text': 'MUE H VIII 162 : 2'},
#          'mods_itemIdentifier': {'_text': 'BM1049627'}}]}}],
#     'mods_accessCondition': {'_text': 'pdm',
#      '_attrib': {'type': 'use and reproduction',
#       'xlink_href': 'https://creativecommons.org/publicdomain/mark/1.0',
#       'displayLabel': 'Public Domain Mark'}},
#     'mods_extension': {'vl_originInfo': {'_attrib': {'displayLabel': 'dc'},
#       'mods_dateCreated': [{'_text': '1821',
#         '_attrib': {'encoding': 'w3cdtf', 'point': 'start'}},
#        {'_text': '1822', '_attrib': {'encoding': 'w3cdtf', 'point': 'end'}}]},
#      '{http://visuallibrary.net/vlz/1.0/}info': {'_attrib': {'version': '2'}}},
#     'mods_recordInfo': {'mods_descriptionStandard': {'_text': 'rda'},
#      'mods_recordContentSource': {'_text': 'SzZuIDS BS/BE A100',
#       '_attrib': {'authority': 'marcorg'}},
#      'mods_recordCreationDate': {'_text': '041020',
#       '_attrib': {'encoding': 'marc'}},
#      'mods_recordChangeDate': {'_text': '20201224025418.0',
#       '_attrib': {'encoding': 'iso8601'}},
#      'mods_recordIdentifier': {'_text': '99116792284005511',
#       '_attrib': {'source': 'bes_1'}},
#      'mods_recordOrigin': {'_text': 'Converted from MARCXML to MODS version 3.6 using MARC21slim2MODS3-6.xsl\n\t\t\t\t(Revision 1.119 2018/06/21)'},
#      'mods_languageOfCataloging': {'mods_languageTerm': {'_text': 'ger',
#        '_attrib': {'authority': 'iso639-2b', 'type': 'code'}}}}}}},
#  {'header': {'identifier': {'_text': 'oai:www.e-rara.ch:1757931'},
#    'datestamp': {'_text': '2012-08-31T09:24:59Z'},
#    'setSpec': [{'_text': 'bes_1'},
#     {'_text': 'book'},
#     {'_text': 'collections'},
#     {'_text': 'bernensia'},
#     {'_text': 'ch'},
#     {'_text': 'ch19'}]},
#   'metadata': {'{http://www.loc.gov/mods/v3}mods': {'_attrib': {'version': '3.6',
#      'xsi_schemaLocation': 'http://www.loc.gov/mods/v3 http://www.loc.gov/standards/mods/v3/mods-3-6.xsd'},
#     'mods_titleInfo': {'mods_title': {'_text': 'Berner Stadtchronik'},
#      'mods_subTitle': {'_text': 'Notizen aus der bernischen Geschichte auf alle Tage des Jahres zusammengestellt'}},
#     'mods_name': {'_attrib': {'type': 'personal', 'usage': 'primary'},
#      'mods_namePart': {'_text': 'Sterchi, Jakob'}},
#     'mods_typeOfResource': {'_text': 'text'},
#     'mods_originInfo': {'mods_place': [{'mods_placeTerm': {'_text': 'sz',
#         '_attrib': {'type': 'code', 'authority': 'marccountry'}}},
#       {'mods_placeTerm': {'_text': 'Bern', '_attrib': {'type': 'text'}}}],
#      'mods_publisher': {'_text': 'Druck und Verlag des "Berner Tagblatt"'},
#      'mods_dateIssued': [{'_text': '1895-1896'},
#       {'_text': '1895',
#        '_attrib': {'encoding': 'w3cdtf', 'point': 'start', 'keyDate': 'yes'}},
#       {'_text': '1896', '_attrib': {'encoding': 'w3cdtf', 'point': 'end'}}],
#      'mods_issuance': {'_text': 'multipart monograph'}},
#     'mods_language': {'mods_languageTerm': {'_text': 'ger',
#       '_attrib': {'authority': 'iso639-2b', 'type': 'code'}}},
#     'mods_physicalDescription': {'mods_form': [{'_text': 'print',
#        '_attrib': {'authority': 'marcform'}},
#       {'_text': 'electronic resource',
#        '_attrib': {'authority': 'marccategory'}},
#       {'_text': 'remote', '_attrib': {'authority': 'marcsmd'}}],
#      'mods_extent': {'_text': '2 Bde.'}},
#     'mods_note': {'_text': 'von J. Sterchi',
#      '_attrib': {'type': 'statement of responsibility', 'altRepGroup': '00'}},
#     'mods_identifier': {'_text': '10.3931/e-rara-7085',
#      '_attrib': {'type': 'doi'}},
#     'mods_location': [{'mods_url': {'_text': 'http://dx.doi.org/10.3931/e-rara-7085',
#        '_attrib': {'displayLabel': 'electronic resource',
#         'usage': 'primary display',
#         'note': 'Digitalisat in e-rara'}}},
#      {'mods_physicalLocation': {'_text': 'B404',
#        '_attrib': {'displayLabel': 'Bern UB Münstergasse',
#         'authority': 'local library code'}},
#       'mods_holdingSimple': {'mods_copyInformation': [{'mods_subLocation': {'_text': 'Magazin'},
#          'mods_shelfLocator': [{'_text': '-'}, {'_text': 'MUE H XXX 87'}],
#          'mods_itemIdentifier': {'_text': '001462217'}},
#         {'mods_subLocation': {'_text': 'Magazin'},
#          'mods_shelfLocator': {'_text': 'MUE H XXX 87 a'},
#          'mods_itemIdentifier': {'_text': 'BM1049622'}}]}},
#      {'mods_physicalLocation': {'_text': 'B555',
#        '_attrib': {'displayLabel': 'Bern UB Mittelstrasse',
#         'authority': 'local library code'}},
#       'mods_holdingSimple': {'mods_copyInformation': [{'mods_subLocation': {'_text': 'Rara'},
#          'mods_shelfLocator': [{'_text': '-'}, {'_text': 'KMU YA 2723 : 1'}],
#          'mods_itemIdentifier': {'_text': 'DSVN2694328'}},
#         {'mods_subLocation': {'_text': 'Rara'},
#          'mods_shelfLocator': {'_text': 'KMU YA 2723 : 2'},
#          'mods_itemIdentifier': {'_text': 'DSVN2694329'}}]}}],
#     'mods_accessCondition': {'_text': 'pdm',
#      '_attrib': {'type': 'use and reproduction',
#       'xlink_href': 'https://creativecommons.org/publicdomain/mark/1.0',
#       'displayLabel': 'Public Domain Mark'}},
#     'mods_extension': {'vl_originInfo': {'_attrib': {'displayLabel': 'dc'},
#       'mods_dateCreated': [{'_text': '1895',
#         '_attrib': {'encoding': 'w3cdtf', 'point': 'start'}},
#        {'_text': '1896', '_attrib': {'encoding': 'w3cdtf', 'point': 'end'}}]},
#      '{http://visuallibrary.net/vlz/1.0/}info': {'_attrib': {'version': '2'}}},
#     'mods_recordInfo': {'mods_descriptionStandard': {'_text': 'kids'},
#      'mods_recordContentSource': {'_text': 'SLB',
#       '_attrib': {'authority': 'marcorg'}},
#      'mods_recordCreationDate': {'_text': '950220',
#       '_attrib': {'encoding': 'marc'}},
#      'mods_recordChangeDate': {'_text': '20201224200802.0',
#       '_attrib': {'encoding': 'iso8601'}},
#      'mods_recordIdentifier': {'_text': '99116894793205511',
#       '_attrib': {'source': 'bes_1'}},
#      'mods_recordOrigin': {'_text': 'Converted from MARCXML to MODS version 3.6 using MARC21slim2MODS3-6.xsl\n\t\t\t\t(Revision 1.119 2018/06/21)'}}}}},
#  {'header': {'identifier': {'_text': 'oai:www.e-rara.ch:1395833'},
#    'datestamp': {'_text': '2012-09-26T14:23:16Z'},
#    'setSpec': [{'_text': 'bes_1'},
#     {'_text': 'journal'},
#     {'_text': 'collections'},
#     {'_text': 'bernensia'},
#     {'_text': 'ch'},
#     {'_text': 'ch19'}]},
#   'metadata': {'{http://www.loc.gov/mods/v3}mods': {'_attrib': {'version': '3.6',
#      'xsi_schemaLocation': 'http://www.loc.gov/mods/v3 http://www.loc.gov/standards/mods/v3/mods-3-6.xsd'},
#     'mods_titleInfo': [{'mods_title': {'_text': 'Adressbuch der Stadt Bern'}},
#      {'_attrib': {'type': 'alternative'},
#       'mods_title': {'_text': 'Adressbuch der Stadt Bern einschliesslich Bümpliz, Köniz, Liebefeld...'}},
#      {'_attrib': {'type': 'alternative'},
#       'mods_title': {'_text': 'Adressbuch der Stadt Bern und Umgebung'}},
#      {'_attrib': {'type': 'alternative'},
#       'mods_title': {'_text': 'Adress-Kalender der Stadt Bern'}}],
#     'mods_typeOfResource': {'_text': 'text'},
#     'mods_genre': [{'_text': 'periodical', '_attrib': {'authority': 'marcgt'}},
#      {'_text': 'Text', '_attrib': {'authority': 'rdacontent'}},
#      {'_text': 'Zeitschrift', '_attrib': {'authority': 'gnd-content'}}],
#     'mods_originInfo': {'mods_place': [{'mods_placeTerm': {'_text': 'sz',
#         '_attrib': {'type': 'code', 'authority': 'marccountry'}}},
#       {'mods_placeTerm': {'_text': 'Bern', '_attrib': {'type': 'text'}}}],
#      'mods_publisher': {'_text': 'Hallwag'},
#      'mods_dateIssued': [{'_text': '1860',
#        '_attrib': {'encoding': 'w3cdtf', 'point': 'start', 'keyDate': 'yes'}},
#       {'_text': '1957', '_attrib': {'encoding': 'w3cdtf', 'point': 'end'}}],
#      'mods_issuance': {'_text': 'serial'},
#      'mods_frequency': [{'_text': 'Jährlich'},
#       {'_text': 'Completely irregular',
#        '_attrib': {'authority': 'marcfrequency'}}]},
#     'mods_language': {'mods_languageTerm': {'_text': 'ger',
#       '_attrib': {'authority': 'iso639-2b', 'type': 'code'}}},
#     'mods_physicalDescription': {'mods_form': [{'_text': 'print',
#        '_attrib': {'authority': 'marcform'}},
#       {'_text': 'electronic resource',
#        '_attrib': {'authority': 'marccategory'}},
#       {'_text': 'remote', '_attrib': {'authority': 'marcsmd'}},
#       {'_text': 'ohne Hilfsmittel zu benutzen',
#        '_attrib': {'type': 'media', 'authority': 'rdamedia'}},
#       {'_text': 'Computermedien',
#        '_attrib': {'type': 'media', 'authority': 'rdamedia'}},
#       {'_text': 'Band',
#        '_attrib': {'type': 'carrier', 'authority': 'rdacarrier'}},
#       {'_text': 'Online-Ressource',
#        '_attrib': {'type': 'carrier', 'authority': 'rdacarrier'}}],
#      'mods_extent': {'_text': '35 cm'}},
#     'mods_note': [{'_text': '1860 - Jg. 75(1957)',
#       '_attrib': {'type': 'date/sequential designation'}},
#      {'_text': 'Mit Stadtplan (zuerst eingeklebt, später als lose Beilage)'}],
#     'mods_classification': {'_text': '910',
#      '_attrib': {'authority': 'ddc', 'edition': '15'}},
#     'mods_identifier': {'_text': '10.3931/e-rara-4614',
#      '_attrib': {'type': 'doi'}},
#     'mods_relatedItem': [{'_attrib': {'type': 'constituent',
#        'otherType': '1871-1938;1946-1950:',
#        'displayLabel': '1871-1938;1946-1950:'},
#       'mods_titleInfo': {'mods_title': {'_text': 'Stadtplan aus Adressbuch'}}},
#      {'_attrib': {'type': 'constituent',
#        'otherType': '1882:',
#        'displayLabel': '1882:'},
#       'mods_titleInfo': {'mods_title': {'_text': 'Adressbuch der Stadt Bern: Die Häuser-Nummerierung in Bern'}}},
#      {'_attrib': {'type': 'constituent',
#        'otherType': '1939-1945:',
#        'displayLabel': '1939-1945:'},
#       'mods_titleInfo': {'mods_title': {'_text': 'Plan der Stadt Bern mit den umliegenden Gemeinden'}}},
#      {'_attrib': {'type': 'constituent',
#        'otherType': '1951-1972:',
#        'displayLabel': '1951-1972:'},
#       'mods_titleInfo': {'mods_title': {'_text': 'Stadtplan von Bern und Umgebung'}}},
#      {'_attrib': {'type': 'constituent',
#        'otherType': '1972-1980:',
#        'displayLabel': '1972-1980:'},
#       'mods_titleInfo': {'mods_title': {'_text': 'Stadtplan Bern'}}},
#      {'_attrib': {'type': 'constituent',
#        'otherType': '1980-:',
#        'displayLabel': '1980-:'},
#       'mods_titleInfo': {'mods_title': {'_text': 'Bern'}}},
#      {'_attrib': {'type': 'preceding'},
#       'mods_titleInfo': {'mods_title': {'_text': 'Hand- und Adressbuch der Bundesstadt Bern'}},
#       'mods_identifier': {'_text': '003065432', '_attrib': {'type': 'local'}}},
#      {'_attrib': {'type': 'succeeding'},
#       'mods_titleInfo': {'mods_title': {'_text': 'Berner Adressbuch'}}}],
#     'mods_location': [{'mods_physicalLocation': {'_text': 'A125 Jg.1877 ; 1886/87 ; 1897/98 ; 33(1905/06) ; 38(1915/16) ; 44(1925) ; 55(1936) ; 64(1946) ; 68(1950) ; 70(1952) ; 82(1964) ; 92(1974)'},
#       'mods_shelfLocator': {'_text': 'UBW Lexika BE 1'}},
#      {'mods_physicalLocation': {'_text': 'B400 1861, 1866 ; 1868/69 ; 1875 ; 1879 ; 1883/84 ; 1886/87 , 1888/89 ; 1891/92-Jg. 75(1957)'},
#       'mods_shelfLocator': {'_text': 'BeZ Hz V 17'}},
#      {'mods_physicalLocation': {'_text': 'B429 1904/05-1957'},
#       'mods_shelfLocator': {'_text': 'MfK Zbeah-00'}},
#      {'mods_physicalLocation': {'_text': 'B440 Siehe Einzelbände'},
#       'mods_shelfLocator': {'_text': '-'}},
#      {'mods_physicalLocation': {'_text': 'A100 Ausg. 36(1918) ; 38(1920) - 39(1921)'},
#       'mods_shelfLocator': {'_text': 'On 547'}},
#      {'mods_physicalLocation': {'_text': 'BFREE -'},
#       'mods_shelfLocator': {'_text': '-'}},
#      {'mods_url': {'_text': 'http://dx.doi.org/10.3931/e-rara-4614',
#        '_attrib': {'displayLabel': 'electronic resource',
#         'usage': 'primary display',
#         'note': 'Digitalisat in e-rara'}}}],
#     'mods_accessCondition': {'_text': 'pdm',
#      '_attrib': {'type': 'use and reproduction',
#       'xlink_href': 'https://creativecommons.org/publicdomain/mark/1.0',
#       'displayLabel': 'Public Domain Mark'}},
#     'mods_extension': {'vl_originInfo': {'_attrib': {'displayLabel': 'dc'},
#       'mods_dateCreated': [{'_text': '1860',
#         '_attrib': {'encoding': 'w3cdtf', 'point': 'start'}},
#        {'_text': '1957', '_attrib': {'encoding': 'w3cdtf', 'point': 'end'}}]},
#      '{http://visuallibrary.net/vlz/1.0/}info': {'_attrib': {'version': '2'}}},
#     'mods_recordInfo': {'mods_descriptionStandard': {'_text': 'kids'},
#      'mods_recordContentSource': {'_text': 'SzZuIDS BS/BE',
#       '_attrib': {'authority': 'marcorg'}},
#      'mods_recordCreationDate': {'_text': '851101',
#       '_attrib': {'encoding': 'marc'}},
#      'mods_recordChangeDate': {'_text': '20200827154300.0',
#       '_attrib': {'encoding': 'iso8601'}},
#      'mods_recordOrigin': {'_text': 'Converted from MARCXML to MODS version 3.6 using MARC21slim2MODS3-6.xsl\n\t\t\t\t(Revision 1.119 2018/06/21)'},
#      'mods_languageOfCataloging': {'mods_languageTerm': {'_text': 'ger',
#        '_attrib': {'authority': 'iso639-2b', 'type': 'code'}}},
#      'mods_recordIdentifier': {'_text': '99116914771105511',
#       '_attrib': {'source': 'bes_1'}}}}}},
#  {'header': {'identifier': {'_text': 'oai:www.e-rara.ch:2069554'},
#    'datestamp': {'_text': '2012-01-30T10:54:23Z'},
#    'setSpec': [{'_text': 'bes_1'},
#     {'_text': 'book'},
#     {'_text': 'ch'},
#     {'_text': 'ch18'},
#     {'_text': 'collections'},
#     {'_text': 'bernensia'}]},
#   'metadata': {'{http://www.loc.gov/mods/v3}mods': {'_attrib': {'version': '3.6',
#      'xsi_schemaLocation': 'http://www.loc.gov/mods/v3 http://www.loc.gov/standards/mods/v3/mods-3-6.xsd'},
#     'mods_titleInfo': [{'mods_nonSort': {'_text': 'Der ',
#        '_attrib': {'{http://www.w3.org/XML/1998/namespace}space': 'preserve'}},
#       'mods_title': {'_text': 'Familie Ziegler demüthige und unterthänigste Bittschrift'}},
#      {'_attrib': {'type': 'alternative',
#        'displayLabel': 'Modernisierter Titel:'},
#       'mods_title': {'_text': 'Der Familie Ziegler demütige und untertänigste Bittschrift'}}],
#     'mods_typeOfResource': {'_text': 'text'},
#     'mods_genre': {'_text': 'Text', '_attrib': {'authority': 'rdacontent'}},
#     'mods_originInfo': {'mods_place': [{'mods_placeTerm': {'_text': 'sz',
#         '_attrib': {'type': 'code', 'authority': 'marccountry'}}},
#       {'mods_placeTerm': {'_text': '[Bern?]', '_attrib': {'type': 'text'}}}],
#      'mods_publisher': {'_text': '[Verlag nicht ermittelbar]'},
#      'mods_dateIssued': [{'_text': '[ca. 1775]'},
#       {'_text': '1775', '_attrib': {'encoding': 'w3cdtf', 'keyDate': 'yes'}}],
#      'mods_issuance': {'_text': 'single unit'}},
#     'mods_language': {'mods_languageTerm': {'_text': 'ger',
#       '_attrib': {'authority': 'iso639-2b', 'type': 'code'}}},
#     'mods_physicalDescription': {'mods_form': [{'_text': 'print',
#        '_attrib': {'authority': 'marcform'}},
#       {'_text': 'electronic resource',
#        '_attrib': {'authority': 'marccategory'}},
#       {'_text': 'remote', '_attrib': {'authority': 'marcsmd'}},
#       {'_text': 'Computermedien',
#        '_attrib': {'type': 'media', 'authority': 'rdamedia'}},
#       {'_text': 'ohne Hilfsmittel zu benutzen',
#        '_attrib': {'type': 'media', 'authority': 'rdamedia'}},
#       {'_text': 'Online-Ressource',
#        '_attrib': {'type': 'carrier', 'authority': 'rdacarrier'}},
#       {'_text': 'Band',
#        '_attrib': {'type': 'carrier', 'authority': 'rdacarrier'}}],
#      'mods_extent': {'_text': '16 S. ; 36 cm'}},
#     'mods_tableOfContents': {'_text': 'Beylag No. 1 : Extract aus dem Raths-Manual der Stadt Bern (1636). Beylag No. 2 : ; Copia Schreibens Mrghhrn. der Räthe an die Stadt Müllhausen (1644). Beylag No. 3 : ; Artikel in der gedrukten Abzug-Ordnung (1644). Beylag No. 4 : ; Auszug aus dem deutschen Missiven-Buch der Stadt Bern: Der Stadt Müllhausen reciprocierliches Antwort-Schreiben des Abzugs halben ; Vortrag der Familie Ziegler an meine ... Herren der Burger-Cammer'},
#     'mods_note': {'_text': 'Antrag der Familie Ziegler an die Berner Obrigkeit, um das Berner Burgerrecht zu erlangen'},
#     'mods_subject': {'mods_geographic': {'_text': 'Bern',
#       '_attrib': {'authority': 'gnd',
#        'authorityURI': 'http://d-nb.info/gnd/',
#        'valueURI': 'http://d-nb.info/gnd/4005762-8'}}},
#     'mods_identifier': {'_text': '10.3931/e-rara-7826',
#      '_attrib': {'type': 'doi'}},
#     'mods_location': [{'mods_physicalLocation': {'_text': 'B404'},
#       'mods_shelfLocator': {'_text': 'MUE Laut fol 9 : 4'},
#       'mods_holdingSimple': {'mods_copyInformation': {'mods_itemIdentifier': {'_text': 'BM1303827'}}}},
#      {'mods_url': {'_text': 'http://dx.doi.org/10.3931/e-rara-7826',
#        '_attrib': {'displayLabel': 'electronic resource',
#         'usage': 'primary display',
#         'note': 'Digitalisat in e-rara'}}}],
#     'mods_accessCondition': {'_text': 'pdm',
#      '_attrib': {'type': 'use and reproduction',
#       'xlink_href': 'https://creativecommons.org/publicdomain/mark/1.0',
#       'displayLabel': 'Public Domain Mark'}},
#     'mods_extension': {'vl_originInfo': {'_attrib': {'displayLabel': 'dc'},
#       'mods_dateCreated': {'_text': '1775',
#        '_attrib': {'encoding': 'w3cdtf', 'point': 'start'}}},
#      '{http://visuallibrary.net/vlz/1.0/}info': {'_attrib': {'version': '2'}}},
#     'mods_recordInfo': {'mods_descriptionStandard': {'_text': 'kids'},
#      'mods_recordContentSource': {'_text': 'Sz',
#       '_attrib': {'authority': 'marcorg'}},
#      'mods_recordCreationDate': {'_text': '940929',
#       '_attrib': {'encoding': 'marc'}},
#      'mods_recordChangeDate': {'_text': '20200827220100.0',
#       '_attrib': {'encoding': 'iso8601'}},
#      'mods_recordOrigin': {'_text': 'Converted from MARCXML to MODS version 3.6 using MARC21slim2MODS3-6.xsl\n\t\t\t\t(Revision 1.119 2018/06/21)'},
#      'mods_recordIdentifier': {'_text': '99116894928805511',
#       '_attrib': {'source': 'bes_1'}}}}}},
#  {'header': {'identifier': {'_text': 'oai:www.e-rara.ch:1757425'},
#    'datestamp': {'_text': '2012-05-08T13:37:03Z'},
#    'setSpec': [{'_text': 'bes_1'},
#     {'_text': 'book'},
#     {'_text': 'collections'},
#     {'_text': 'bernensia'},
#     {'_text': 'ch'},
#     {'_text': 'ch18'}]},
#   'metadata': {'{http://www.loc.gov/mods/v3}mods': {'_attrib': {'version': '3.6',
#      'xsi_schemaLocation': 'http://www.loc.gov/mods/v3 http://www.loc.gov/standards/mods/v3/mods-3-6.xsd'},
#     'mods_titleInfo': [{'mods_title': {'_text': 'Berner Address-Handbuch der Handelshäuser, Fabrikanten wie auch der Künstler, ansehnlichen gewerbetreibenden Personen und Professionisten im Kanton'}},
#      {'_attrib': {'type': 'alternative'},
#       'mods_title': {'_text': 'Berner Adress-Handbuch der Handelshäuser, Fabrikanten wie auch der Künstler, ansehnlichen gewerbetreibenden Personen und Professionisten im Kanton'}}],
#     'mods_name': {'_attrib': {'type': 'corporate',
#       'authority': 'gnd',
#       'authorityURI': 'http://d-nb.info/gnd/',
#       'valueURI': 'http://d-nb.info/gnd/1086438582,'},
#      'mods_nameIdentifier': {'_text': '(DE-588)1086438582,'},
#      'mods_namePart': {'_text': 'Typographische Societäts-Buchhandlung (Bern)'},
#      'mods_role': [{'mods_roleTerm': {'_text': 'Drucker',
#         '_attrib': {'type': 'text'}}},
#       {'mods_roleTerm': {'_text': 'prt',
#         '_attrib': {'authority': 'marcrelator', 'type': 'code'}}}]},
#     'mods_typeOfResource': {'_text': 'text'},
#     'mods_genre': {'_text': 'Text', '_attrib': {'authority': 'rdacontent'}},
#     'mods_originInfo': {'mods_place': [{'mods_placeTerm': {'_text': 'sz',
#         '_attrib': {'type': 'code', 'authority': 'marccountry'}}},
#       {'mods_placeTerm': {'_text': 'Bern', '_attrib': {'type': 'text'}}}],
#      'mods_publisher': {'_text': 'in der Buchhandlung nebst dem Hotel-de-Musique'},
#      'mods_dateIssued': {'_text': '1795', '_attrib': {'keyDate': 'yes'}},
#      'mods_edition': {'_text': 'Erster Versuch'},
#      'mods_issuance': {'_text': 'single unit'}},
#     'mods_language': {'mods_languageTerm': {'_text': 'ger',
#       '_attrib': {'authority': 'iso639-2b', 'type': 'code'}}},
#     'mods_physicalDescription': {'mods_form': [{'_text': 'print',
#        '_attrib': {'authority': 'marcform'}},
#       {'_text': 'electronic resource',
#        '_attrib': {'authority': 'marccategory'}},
#       {'_text': 'remote', '_attrib': {'authority': 'marcsmd'}},
#       {'_text': 'Computermedien',
#        '_attrib': {'type': 'media', 'authority': 'rdamedia'}},
#       {'_text': 'ohne Hilfsmittel zu benutzen',
#        '_attrib': {'type': 'media', 'authority': 'rdamedia'}},
#       {'_text': 'Online-Ressource',
#        '_attrib': {'type': 'carrier', 'authority': 'rdacarrier'}},
#       {'_text': 'Band',
#        '_attrib': {'type': 'carrier', 'authority': 'rdacarrier'}}],
#      'mods_extent': {'_text': '64 S. ; 17 cm (8°)'}},
#     'mods_note': [{'_text': 'Anhang zu: Johann Georg Heinzmanns Beschreibung der Stadt und Republik Bern...'},
#      {'_text': 'S. 65-72: 1ste Fortsetzung (1796)'}],
#     'mods_subject': {'mods_geographic': {'_text': 'Bern',
#       '_attrib': {'authority': 'gnd',
#        'authorityURI': 'http://d-nb.info/gnd/',
#        'valueURI': 'http://d-nb.info/gnd/4005762-8'}}},
#     'mods_identifier': {'_text': '10.3931/e-rara-7081',
#      '_attrib': {'type': 'doi'}},
#     'mods_location': [{'mods_physicalLocation': {'_text': 'B404 -'},
#       'mods_shelfLocator': {'_text': '-'}},
#      {'mods_physicalLocation': {'_text': 'B434'},
#       'mods_shelfLocator': {'_text': 'StAB BA 795'},
#       'mods_holdingSimple': {'mods_copyInformation': {'mods_itemIdentifier': {'_text': 'DSVN434408'}}}},
#      {'mods_physicalLocation': {'_text': 'B404'},
#       'mods_shelfLocator': {'_text': 'MUE Rar alt 832'},
#       'mods_holdingSimple': {'mods_copyInformation': {'mods_itemIdentifier': {'_text': 'BM1050728'}}}},
#      {'mods_physicalLocation': {'_text': 'B404'},
#       'mods_shelfLocator': {'_text': 'MUE Laut 486 : 2'},
#       'mods_holdingSimple': {'mods_copyInformation': {'mods_itemIdentifier': {'_text': 'BM1808942'}}}},
#      {'mods_physicalLocation': {'_text': 'A100'},
#       'mods_shelfLocator': {'_text': 'VB L 267:6'},
#       'mods_holdingSimple': {'mods_copyInformation': {'mods_itemIdentifier': {'_text': 'DSVN548076'}}}},
#      {'mods_url': {'_text': 'http://dx.doi.org/10.3931/e-rara-7081',
#        '_attrib': {'displayLabel': 'electronic resource',
#         'usage': 'primary display',
#         'note': 'Digitalisat in e-rara'}}}],
#     'mods_accessCondition': {'_text': 'pdm',
#      '_attrib': {'type': 'use and reproduction',
#       'xlink_href': 'https://creativecommons.org/publicdomain/mark/1.0',
#       'displayLabel': 'Public Domain Mark'}},
#     'mods_extension': {'vl_originInfo': {'_attrib': {'displayLabel': 'dc'},
#       'mods_dateCreated': {'_text': '1795',
#        '_attrib': {'encoding': 'w3cdtf', 'point': 'start'}}},
#      '{http://visuallibrary.net/vlz/1.0/}info': {'_attrib': {'version': '2'}}},
#     'mods_recordInfo': {'mods_descriptionStandard': {'_text': 'kids'},
#      'mods_recordContentSource': {'_text': 'SzZuIDS BS/BE B434',
#       '_attrib': {'authority': 'marcorg'}},
#      'mods_recordCreationDate': {'_text': '020812',
#       '_attrib': {'encoding': 'marc'}},
#      'mods_recordChangeDate': {'_text': '20200827212000.0',
#       '_attrib': {'encoding': 'iso8601'}},
#      'mods_recordOrigin': {'_text': 'Converted from MARCXML to MODS version 3.6 using MARC21slim2MODS3-6.xsl\n\t\t\t\t(Revision 1.119 2018/06/21)'},
#      'mods_recordIdentifier': {'_text': '99116804683105511',
#       '_attrib': {'source': 'bes_1'}}}}}},
#  {'header': {'identifier': {'_text': 'oai:www.e-rara.ch:1396731'},
#    'datestamp': {'_text': '2011-04-05T14:34:52Z'},
#    'setSpec': [{'_text': 'bes_1'},
#     {'_text': 'book'},
#     {'_text': 'collections'},
#     {'_text': 'bernensia'},
#     {'_text': 'ch'},
#     {'_text': 'ch19'}]},
#   'metadata': {'{http://www.loc.gov/mods/v3}mods': {'_attrib': {'version': '3.6',
#      'xsi_schemaLocation': 'http://www.loc.gov/mods/v3 http://www.loc.gov/standards/mods/v3/mods-3-6.xsd'},
#     'mods_titleInfo': [{'mods_title': {'_text': 'Geographisch-geschichtliches und Handels-Orts-Lexikon des Kantons Bern'},
#       'mods_subTitle': {'_text': 'nach Amtsbezirken und Kirchgemeinden eingetheilt : statistische und historische Notizen der einzelnen Ortschaften'}},
#      {'_attrib': {'type': 'alternative'},
#       'mods_title': {'_text': 'Orts-Lexikon des Kantons Bern'}}],
#     'mods_name': {'_attrib': {'type': 'personal',
#       'usage': 'primary',
#       'authority': 'gnd',
#       'authorityURI': 'http://d-nb.info/gnd/',
#       'valueURI': 'http://d-nb.info/gnd/127809651,'},
#      'mods_nameIdentifier': {'_text': '(DE-588)127809651,'},
#      'mods_namePart': [{'_text': 'Raemy, Alfred de'},
#       {'_text': '1825-1909', '_attrib': {'type': 'date'}}],
#      'mods_role': [{'mods_roleTerm': {'_text': 'Verfasser',
#         '_attrib': {'type': 'text'}}},
#       {'mods_roleTerm': {'_text': 'aut',
#         '_attrib': {'authority': 'marcrelator', 'type': 'code'}}}]},
#     'mods_typeOfResource': {'_text': 'text'},
#     'mods_genre': {'_text': 'Text', '_attrib': {'authority': 'rdacontent'}},
#     'mods_originInfo': {'mods_place': [{'mods_placeTerm': {'_text': 'sz',
#         '_attrib': {'type': 'code', 'authority': 'marccountry'}}},
#       {'mods_placeTerm': {'_text': 'Freiburg', '_attrib': {'type': 'text'}}}],
#      'mods_publisher': {'_text': 'Herausgegeben im Selbstverlag von Alfred Raemy'},
#      'mods_dateIssued': {'_text': '1890', '_attrib': {'keyDate': 'yes'}},
#      'mods_issuance': {'_text': 'single unit'}},
#     'mods_language': {'mods_languageTerm': {'_text': 'ger',
#       '_attrib': {'authority': 'iso639-2b', 'type': 'code'}}},
#     'mods_physicalDescription': {'mods_form': [{'_text': 'print',
#        '_attrib': {'authority': 'marcform'}},
#       {'_text': 'electronic resource',
#        '_attrib': {'authority': 'marccategory'}},
#       {'_text': 'remote', '_attrib': {'authority': 'marcsmd'}},
#       {'_text': 'ohne Hilfsmittel zu benutzen',
#        '_attrib': {'type': 'media', 'authority': 'rdamedia'}},
#       {'_text': 'Computermedien',
#        '_attrib': {'type': 'media', 'authority': 'rdamedia'}},
#       {'_text': 'Band',
#        '_attrib': {'type': 'carrier', 'authority': 'rdacarrier'}},
#       {'_text': 'Online-Ressource',
#        '_attrib': {'type': 'carrier', 'authority': 'rdacarrier'}}],
#      'mods_extent': {'_text': '443 Seiten ; 23 cm (8°)'}},
#     'mods_abstract': {'_text': 'Angabe der verschiedenen Behörden und Verwaltungen - Verzeichnis der Geschlechter der Gemeinde Burger - Angabe der hauptsächlichsten Handelshäuser'},
#     'mods_note': {'_text': '[Alfred Raemy]',
#      '_attrib': {'type': 'statement of responsibility', 'altRepGroup': '00'}},
#     'mods_subject': [{'_attrib': {'authority': 'idsbb'},
#       'mods_topic': {'_text': 'Ortsnamen'},
#       'mods_geographic': {'_text': 'Bern (Kanton)'},
#       'mods_genre': {'_text': 'Wörterbuch'}},
#      {'_attrib': {'authority': 'stw'},
#       'mods_topic': {'_text': 'Volkswirtschaft'}}],
#     'mods_classification': {'_text': '949.4',
#      '_attrib': {'authority': 'ddc', 'edition': '15'}},
#     'mods_identifier': {'_text': '10.3931/e-rara-4615',
#      '_attrib': {'type': 'doi'}},
#     'mods_location': [{'mods_physicalLocation': {'_text': 'B434 -'},
#       'mods_shelfLocator': {'_text': '-'}},
#      {'mods_physicalLocation': {'_text': 'B404 -'},
#       'mods_shelfLocator': {'_text': '-'}},
#      {'mods_physicalLocation': {'_text': 'B465'},
#       'mods_shelfLocator': {'_text': 'JBB 1.400/ 50'},
#       'mods_holdingSimple': {'mods_copyInformation': {'mods_itemIdentifier': {'_text': 'BM1364711'}}}},
#      {'mods_physicalLocation': {'_text': 'B434'},
#       'mods_shelfLocator': {'_text': 'StAB A 3835'},
#       'mods_holdingSimple': {'mods_copyInformation': {'mods_itemIdentifier': {'_text': 'DSVN1812034'}}}},
#      {'mods_physicalLocation': {'_text': 'B400'},
#       'mods_shelfLocator': {'_text': 'BeM ZB Geogr XVII 261'},
#       'mods_holdingSimple': {'mods_copyInformation': {'mods_itemIdentifier': {'_text': '001075973'}}}},
#      {'mods_physicalLocation': {'_text': 'B404'},
#       'mods_shelfLocator': {'_text': 'MUE H II 337'},
#       'mods_holdingSimple': {'mods_copyInformation': {'mods_itemIdentifier': {'_text': 'BM1992476'}}}},
#      {'mods_physicalLocation': {'_text': 'B404'},
#       'mods_shelfLocator': {'_text': 'MUE H XXV 17'},
#       'mods_holdingSimple': {'mods_copyInformation': {'mods_itemIdentifier': {'_text': 'DSVN1859131'}}}},
#      {'mods_physicalLocation': {'_text': 'B440'},
#       'mods_shelfLocator': {'_text': 'BBB Mül S 551 (3)'},
#       'mods_holdingSimple': {'mods_copyInformation': {'mods_itemIdentifier': {'_text': 'DSVN1859133'}}}},
#      {'mods_physicalLocation': {'_text': 'B424'},
#       'mods_shelfLocator': {'_text': 'SBB G 12'},
#       'mods_holdingSimple': {'mods_copyInformation': {'mods_itemIdentifier': {'_text': 'BM42420679'}}}},
#      {'mods_physicalLocation': {'_text': 'A125'},
#       'mods_shelfLocator': {'_text': 'SWA Vo H I 4 BE'},
#       'mods_holdingSimple': {'mods_copyInformation': {'mods_itemIdentifier': {'_text': 'A1001561883'}}}},
#      {'mods_physicalLocation': {'_text': 'B434'},
#       'mods_shelfLocator': {'_text': 'StAB A 856'},
#       'mods_holdingSimple': {'mods_copyInformation': {'mods_itemIdentifier': {'_text': 'DSVN2442892'}}}},
#      {'mods_physicalLocation': {'_text': 'B434'},
#       'mods_shelfLocator': {'_text': 'StAB A 856 a'},
#       'mods_holdingSimple': {'mods_copyInformation': {'mods_itemIdentifier': {'_text': 'DSVN2442893'}}}},
#      {'mods_physicalLocation': {'_text': 'B400'},
#       'mods_shelfLocator': {'_text': 'BeM ZB SAC alt  382'},
#       'mods_holdingSimple': {'mods_copyInformation': {'mods_itemIdentifier': {'_text': 'BM1677625'}}}},
#      {'mods_url': {'_text': 'http://dx.doi.org/10.3931/e-rara-4615',
#        '_attrib': {'displayLabel': 'electronic resource',
#         'usage': 'primary display',
#         'note': 'Digitalisat in e-rara'}}}],
#     'mods_accessCondition': {'_text': 'pdm',
#      '_attrib': {'type': 'use and reproduction',
#       'xlink_href': 'https://creativecommons.org/publicdomain/mark/1.0',
#       'displayLabel': 'Public Domain Mark'}},
#     'mods_extension': {'vl_originInfo': {'_attrib': {'displayLabel': 'dc'},
#       'mods_dateCreated': {'_text': '1890',
#        '_attrib': {'encoding': 'w3cdtf', 'point': 'start'}}},
#      '{http://visuallibrary.net/vlz/1.0/}info': {'_attrib': {'version': '2'}}},
#     'mods_recordInfo': {'mods_descriptionStandard': {'_text': 'rda'},
#      'mods_recordContentSource': {'_text': 'SzZuIDS BS/BE B465',
#       '_attrib': {'authority': 'marcorg'}},
#      'mods_recordCreationDate': {'_text': '900711',
#       '_attrib': {'encoding': 'marc'}},
#      'mods_recordChangeDate': {'_text': '20200805192800.0',
#       '_attrib': {'encoding': 'iso8601'}},
#      'mods_recordOrigin': {'_text': 'Converted from MARCXML to MODS version 3.6 using MARC21slim2MODS3-6.xsl\n\t\t\t\t(Revision 1.119 2018/06/21)'},
#      'mods_languageOfCataloging': {'mods_languageTerm': {'_text': 'ger',
#        '_attrib': {'authority': 'iso639-2b', 'type': 'code'}}},
#      'mods_recordIdentifier': {'_text': '99116788076605511',
#       '_attrib': {'source': 'bes_1'}}}}}},
#  {'header': {'identifier': {'_text': 'oai:www.e-rara.ch:1757509'},
#    'datestamp': {'_text': '2012-08-31T09:10:52Z'},
#    'setSpec': [{'_text': 'bes_1'},
#     {'_text': 'book'},
#     {'_text': 'collections'},
#     {'_text': 'bernensia'},
#     {'_text': 'ch'},
#     {'_text': 'ch19'}]},
#   'metadata': {'{http://www.loc.gov/mods/v3}mods': {'_attrib': {'version': '3.6',
#      'xsi_schemaLocation': 'http://www.loc.gov/mods/v3 http://www.loc.gov/standards/mods/v3/mods-3-6.xsd'},
#     'mods_titleInfo': {'mods_title': {'_text': 'Adressbuch der Stadt Bern'}},
#     'mods_name': {'_attrib': {'type': 'personal'},
#      'mods_namePart': {'_text': 'Messerli, Johann Ch.'}},
#     'mods_typeOfResource': {'_text': 'text'},
#     'mods_genre': {'_text': 'Text', '_attrib': {'authority': 'rdacontent'}},
#     'mods_originInfo': {'mods_place': [{'mods_placeTerm': {'_text': 'sz',
#         '_attrib': {'type': 'code', 'authority': 'marccountry'}}},
#       {'mods_placeTerm': {'_text': 'Bern', '_attrib': {'type': 'text'}}}],
#      'mods_publisher': {'_text': 'C. A. Jenni'},
#      'mods_dateIssued': {'_text': '1822', '_attrib': {'keyDate': 'yes'}},
#      'mods_issuance': {'_text': 'single unit'}},
#     'mods_language': {'mods_languageTerm': {'_text': 'ger',
#       '_attrib': {'authority': 'iso639-2b', 'type': 'code'}}},
#     'mods_physicalDescription': {'mods_form': [{'_text': 'print',
#        '_attrib': {'authority': 'marcform'}},
#       {'_text': 'electronic resource',
#        '_attrib': {'authority': 'marccategory'}},
#       {'_text': 'remote', '_attrib': {'authority': 'marcsmd'}},
#       {'_text': 'Computermedien',
#        '_attrib': {'type': 'media', 'authority': 'rdamedia'}},
#       {'_text': 'ohne Hilfsmittel zu benutzen',
#        '_attrib': {'type': 'media', 'authority': 'rdamedia'}},
#       {'_text': 'Online-Ressource',
#        '_attrib': {'type': 'carrier', 'authority': 'rdacarrier'}},
#       {'_text': 'Band',
#        '_attrib': {'type': 'carrier', 'authority': 'rdacarrier'}}],
#      'mods_extent': {'_text': "62 S. ; 8'"}},
#     'mods_note': {'_text': '("Verfasser: Joh. Ch. Messerli")',
#      '_attrib': {'type': 'statement of responsibility', 'altRepGroup': '00'}},
#     'mods_identifier': {'_text': '10.3931/e-rara-7082',
#      '_attrib': {'type': 'doi'}},
#     'mods_location': [{'mods_physicalLocation': {'_text': 'A100'},
#       'mods_shelfLocator': {'_text': 'VB G 217:3'},
#       'mods_holdingSimple': {'mods_copyInformation': {'mods_itemIdentifier': {'_text': 'A1001236755'}}}},
#      {'mods_physicalLocation': {'_text': 'B400'},
#       'mods_shelfLocator': {'_text': 'BeM Rar 307'},
#       'mods_holdingSimple': {'mods_copyInformation': {'mods_itemIdentifier': {'_text': 'BM1050727'}}}},
#      {'mods_url': {'_text': 'http://dx.doi.org/10.3931/e-rara-7082',
#        '_attrib': {'displayLabel': 'electronic resource',
#         'usage': 'primary display',
#         'note': 'Digitalisat in e-rara'}}}],
#     'mods_accessCondition': {'_text': 'pdm',
#      '_attrib': {'type': 'use and reproduction',
#       'xlink_href': 'https://creativecommons.org/publicdomain/mark/1.0',
#       'displayLabel': 'Public Domain Mark'}},
#     'mods_extension': {'vl_originInfo': {'_attrib': {'displayLabel': 'dc'},
#       'mods_dateCreated': {'_text': '1822',
#        '_attrib': {'encoding': 'w3cdtf', 'point': 'start'}}},
#      '{http://visuallibrary.net/vlz/1.0/}info': {'_attrib': {'version': '2'}}},
#     'mods_recordInfo': {'mods_descriptionStandard': {'_text': 'kids'},
#      'mods_recordContentSource': {'_text': 'SzZuIDS BS/BE A100',
#       '_attrib': {'authority': 'marcorg'}},
#      'mods_recordCreationDate': {'_text': '021219',
#       '_attrib': {'encoding': 'marc'}},
#      'mods_recordChangeDate': {'_text': '20200827212600.0',
#       '_attrib': {'encoding': 'iso8601'}},
#      'mods_recordOrigin': {'_text': 'Converted from MARCXML to MODS version 3.6 using MARC21slim2MODS3-6.xsl\n\t\t\t\t(Revision 1.119 2018/06/21)'},
#      'mods_recordIdentifier': {'_text': '99116775744705511',
#       '_attrib': {'source': 'bes_1'}}}}}}]

# %% [markdown]
# The stored data **can be used just the same way** as the direct accessed one, like for instance for the `mods_titleInfo` element. Note that the order of the records is shuffled now.

# %%
reader = JSONReader('poly_metadata')
for record in reader:
    print(record.header.identifier._text)
    print(record.get(['metadata', '{http://www.loc.gov/mods/v3}mods', 'mods_titleInfo', 'mods_title', '_text']))
    print(record.get(['metadata', '{http://www.loc.gov/mods/v3}mods', 'mods_genre', '_text']))
    print('---')
# Out:
# oai:www.e-rara.ch:1757592
# Hand- und Adressbuch der Bundesstadt Bern
# ['periodical', 'Text', 'Zeitschrift']
# ---
# oai:www.e-rara.ch:1397203
# Adressenbuch der Republik Bern
# Text
# ---
# oai:www.e-rara.ch:4709578
# ['Verzeichniss aller auf der Stadt-Bibliothek in Bern vorhandenen gedruckten Werke', 'Verzeichnis aller auf der Stadtbibliothek in Bern vorhandenen gedruckten Werke', '[Erstes - Drittes] Supplement zum Catalog der Stadt-Bibliothek in Bern']
# None
# ---
# oai:www.e-rara.ch:1758267
# ['Sammlung der Grabschriften der gegenwärtigen Bernischen Gottesäcker Monbijou, Rosengarten und Klösterlein', 'Fortsetzung der Sammlung der Grabschriften der ... Gottesäcker Monbijou und Rosengarten']
# None
# ---
# oai:www.e-rara.ch:1757931
# Berner Stadtchronik
# None
# ---
# oai:www.e-rara.ch:1395833
# ['Adressbuch der Stadt Bern', 'Adressbuch der Stadt Bern einschliesslich Bümpliz, Köniz, Liebefeld...', 'Adressbuch der Stadt Bern und Umgebung', 'Adress-Kalender der Stadt Bern']
# ['periodical', 'Text', 'Zeitschrift']
# ---
# oai:www.e-rara.ch:2069554
# ['Familie Ziegler demüthige und unterthänigste Bittschrift', 'Der Familie Ziegler demütige und untertänigste Bittschrift']
# Text
# ---
# oai:www.e-rara.ch:1757425
# ['Berner Address-Handbuch der Handelshäuser, Fabrikanten wie auch der Künstler, ansehnlichen gewerbetreibenden Personen und Professionisten im Kanton', 'Berner Adress-Handbuch der Handelshäuser, Fabrikanten wie auch der Künstler, ansehnlichen gewerbetreibenden Personen und Professionisten im Kanton']
# Text
# ---
# oai:www.e-rara.ch:1396731
# ['Geographisch-geschichtliches und Handels-Orts-Lexikon des Kantons Bern', 'Orts-Lexikon des Kantons Bern']
# Text
# ---
# oai:www.e-rara.ch:1757509
# Adressbuch der Stadt Bern
# Text
# ---

# %%
# One more example: The 'mods_note' element and its '_attrib' sub-element
reader = JSONReader('poly_metadata')
for record in reader:
    print(record.header.identifier._text)
    print(record.get(['metadata', '{http://www.loc.gov/mods/v3}mods', 'mods_note', '_text']))
    print(record.get(['metadata', '{http://www.loc.gov/mods/v3}mods', 'mods_note', '_attrib', 'type']))
    print('---')
# Out:
# oai:www.e-rara.ch:1757592
# 1859
# date/sequential designation
# ---
# oai:www.e-rara.ch:1397203
# ['Bearb. und hrsg. von C. v. Sommerlatt', 'Beigebunden: Ergänzungsheft zu dem Adressbuch der Republik Bern von 1836. Erschienen im April 1839, Thun.']
# ['statement of responsibility', None]
# ---
# oai:www.e-rara.ch:4709578
# ['Erster alphabetischer Katalog der damaligen Stadtbibliothek, verfasst vom Oberbibliothekar F. Tscharner', 'Theil 1 (1811): XLVIII, 470 S.; Theil 2 (1811): 508 S.; Theil 3 (1811): 462 S.; Suppl. (1839): XXII, 287 S.; Suppl. 2 (1847): 224 S.; Suppl. 3 (1856): 390 S.', 'Betrifft die Handschrift Cod. 757.I der Burgerbibliothek Bern (S. 212).']
# [None, None, None]
# ---
# oai:www.e-rara.ch:1758267
# ['Hrsg. von Christian Albrecht Jenni ; Fortsetzung der Sammlung der Grabschriften der ... Gottesäcker Monbijou und Rosengarten', 'Herausgeber am Ende des Vorworts von Band 2: "C. A. Jenni"']
# ['statement of responsibility', None]
# ---
# oai:www.e-rara.ch:1757931
# von J. Sterchi
# statement of responsibility
# ---
# oai:www.e-rara.ch:1395833
# ['1860 - Jg. 75(1957)', 'Mit Stadtplan (zuerst eingeklebt, später als lose Beilage)']
# ['date/sequential designation', None]
# ---
# oai:www.e-rara.ch:2069554
# Antrag der Familie Ziegler an die Berner Obrigkeit, um das Berner Burgerrecht zu erlangen
# None
# ---
# oai:www.e-rara.ch:1757425
# ['Anhang zu: Johann Georg Heinzmanns Beschreibung der Stadt und Republik Bern...', 'S. 65-72: 1ste Fortsetzung (1796)']
# [None, None]
# ---
# oai:www.e-rara.ch:1396731
# [Alfred Raemy]
# statement of responsibility
# ---
# oai:www.e-rara.ch:1757509
# ("Verfasser: Joh. Ch. Messerli")
# statement of responsibility
# ---

# %% [markdown]
# Of course, there is also the way to read out certain metadata fields **via basic dot-notation**. But this will take a bit more of code to cope with the list vs. single value issue.

# %%
reader = JSONReader('poly_metadata')
for record in reader:
    print(record.header.identifier._text)
    if 'mods_genre' in record.metadata['{http://www.loc.gov/mods/v3}mods']:
        if isinstance(record.metadata['{http://www.loc.gov/mods/v3}mods'].mods_genre, list):
            le = len(record.metadata['{http://www.loc.gov/mods/v3}mods'].mods_genre)
            for i in range(le):
                print(record.metadata['{http://www.loc.gov/mods/v3}mods'].mods_genre[i]._text)
        else:
            print(record.metadata['{http://www.loc.gov/mods/v3}mods'].mods_genre._text)
    else: 
        print(None)
    print('---')
# Out:
# oai:www.e-rara.ch:1757592
# periodical
# Text
# Zeitschrift
# ---
# oai:www.e-rara.ch:1397203
# Text
# ---
# oai:www.e-rara.ch:4709578
# None
# ---
# oai:www.e-rara.ch:1758267
# None
# ---
# oai:www.e-rara.ch:1757931
# None
# ---
# oai:www.e-rara.ch:1395833
# periodical
# Text
# Zeitschrift
# ---
# oai:www.e-rara.ch:2069554
# Text
# ---
# oai:www.e-rara.ch:1757425
# Text
# ---
# oai:www.e-rara.ch:1396731
# Text
# ---
# oai:www.e-rara.ch:1757509
# Text
# ---

# %% [markdown]
# ## 2 Direct metadata access via OAI-PMH

# %% [markdown]
# Unfortunately, the Polymatheia library doesn't offer methods for *all* OAI verbs. For instance, there is no `ListIdentifiers` method (which delivers only the identifiers of a given set) and no `GetRecord` for retrieving the metadata of a certain item using its e-rara ID.
#
# That's where especially the common libraries **requests** and  **BeautifulSoup** come into play, and more manual coding is needed.

# %% [markdown]
# ### 2.0 Prerequisites

# %%
# Load the necessary libraries
import requests                                 # request URLs
from bs4 import BeautifulSoup as soup           # webscrape and parse HTML and XML
import lxml                                     # XML parser supported by bs4
                                                # call with soup(markup, 'lxml-xml' OR 'xml')
import os                                       # navigate and manipulate file directories
import time                                     # work with time stamps
import pandas as pd                             # pandas is the Python standard library to work with dataframes
from IPython.display import IFrame              # embed website views in jupyter notebook
import math                                     # work with mathematical functions
import re                                       # work with regular expressions
print("Succesfully imported necessary libraries")
# Out:
# Succesfully imported necessary libraries

# %% [markdown]
# https://www.e-rara.ch/oai/ will be the **base URL** for all OAI requests. To make life easier we put it into the variable `oai`.

# %%
oai = 'https://www.e-rara.ch/oai/'

# %% [markdown]
# ### 2.1 Start with the native OAI interface

# %% [markdown]
# The very **core of all operations on the OAI interface** will be a small function called `load_xml()`. It simply requests the base URL with the various parameters and decodes the answer to XML. Therefore, it can be used with all OAI verbs and their respective parameters.

# %%
def load_xml(params):
    '''
    Accesses the OAI interface according to given parameters and scrapes its content.
    Parameters:
    All available native OAI verbs and parameter/value pairs.
    '''
    base_url = oai
    response = requests.get(base_url, params=params)
    output_soup = soup(response.content, "lxml")
    return output_soup

# %% [markdown]
# You may use it to read out the basic `Identify` response of the OAI interface.
#
# Note, that the parameters to be used by the `load_xml` function are the same as in the genuine URL `https://www.e-rara.ch/oai?verb=Identify`. That is, `verb` as the parameter key, and `Identify` as the parameter value. Therefore, we need a **parameter key-value pair**, which will be indicated by enclosing them in curly braces.

# %%
xml_soup = load_xml({'verb': 'Identify'})
xml_soup
# Out:
# <html><body><oai-pmh xmlns="http://www.openarchives.org/OAI/2.0/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemalocation="http://www.openarchives.org/OAI/2.0/ http://www.openarchives.org/OAI/2.0/OAI-PMH.xsd"><responsedate>2021-06-23T16:28:36Z</responsedate><request verb="Identify">https://www.e-rara.ch/oai/</request><identify><repositoryname>Visual Library Server</repositoryname><baseurl>https://www.e-rara.ch/oai/</baseurl><protocolversion>2.0</protocolversion><adminemail>issue-erara@library.ethz.ch</adminemail><earliestdatestamp>2009-11-10T09:38:31Z</earliestdatestamp><deletedrecord>no</deletedrecord><granularity>YYYY-MM-DDThh:mm:ssZ</granularity></identify></oai-pmh></body></html>

# %% [markdown]
# You can easily check with the `IFrame` method underneath.

# %%
IFrame('https://www.e-rara.ch/oai?verb=Identify', width=970, height=330)
# Out:
#         <iframe
#             width="970"
#             height="330"
#             src="https://www.e-rara.ch/oai?verb=Identify"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ### 2.2 Download metadata records

# %% [markdown]
# The same can be done with the `GetRecord` verb, here `metadataPrefix`and `identifier` are mandatory parameters, naturally. Note, that as the identifier is an integer, you can discard the quotation marks used with the other parameter key-value pairs - anyway, often it's a good idea to keep these quotation marks regularly.

# %%
# Example for accessing a single metadata record
# https://www.e-rara.ch/oai?verb=GetRecord&metadataPrefix=oai_dc&identifier=20329783

xml_soup = load_xml({'verb': 'GetRecord', 'metadataPrefix': 'oai_dc', 'identifier': 20329783})
xml_soup
# Out:
# <html><body><oai-pmh xmlns="http://www.openarchives.org/OAI/2.0/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemalocation="http://www.openarchives.org/OAI/2.0/ http://www.openarchives.org/OAI/2.0/OAI-PMH.xsd"><responsedate>2021-06-23T16:28:37Z</responsedate><request identifier="20329783" metadataprefix="oai_dc" verb="GetRecord">https://www.e-rara.ch/oai/</request><getrecord><record><header><identifier>oai:www.e-rara.ch:20329783</identifier><datestamp>2018-11-12T15:27:09Z</datestamp><setspec>zut</setspec><setspec>book</setspec></header><metadata><oai_dc:dc xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:oai_dc="http://www.openarchives.org/OAI/2.0/oai_dc/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemalocation="http://www.openarchives.org/OAI/2.0/oai_dc/ http://www.openarchives.org/OAI/2.0/oai_dc.xsd"><dc:title>Bibliotheca magica et pneumatica, oder, wissenschaftlich geordnete Bibliographie der wichtigsten in das Gebiet des Zauber-, Wunder-, Geister- und sonstigen Aberglaubens vorzüglich älterer Zeit einschlagenden Werke : mit Angabe der aus diesen Wissenschaften auf der königl. Sächs. Oeff. Bibliothek zu Dresden befindlichen Schriften : ein Beitrag zur sittengeschichtlichen Literatur</dc:title><dc:creator>Graesse, Johann Georg Theodor</dc:creator><dc:subject>Esoterik</dc:subject><dc:subject>Okkultismus</dc:subject><dc:description>zusammengestellt und mit einem doppeltem Register versehen von Dr. Johann Georg Theodor Grässe</dc:description><dc:publisher>Verlag von Wilhelm Engelmann</dc:publisher><dc:date>1843</dc:date><dc:type>Text</dc:type><dc:type>Book</dc:type><dc:format>IV, 175 Seiten ; 22 cm (8°)</dc:format><dc:identifier>doi:10.3931/e-rara-73231</dc:identifier><dc:identifier>https://www.e-rara.ch/zut/doi/10.3931/e-rara-73231</dc:identifier><dc:identifier>system:990023964540205503</dc:identifier><dc:relation>vignette : https://www.e-rara.ch/zut/titlepage/doi/10.3931/e-rara-73231/128</dc:relation><dc:language>ger</dc:language><dc:coverage>Leipzig</dc:coverage><dc:rights>pdm</dc:rights></oai_dc:dc></metadata></record></getrecord></oai-pmh></body></html>

# %% [markdown]
# Again before downloading, first make a dedicated folder for the retrieved metadata.

# %%
print(os.getcwd())                        # print current working directory
# Out:
# C:\Users\kwoit\Documents\GitHub\e-rara-access\data

# %% [markdown]
# In case you might change your directory you can easily do this with `os.chdir` or `os.chdir(os.pardir)`. While `os.chdir()` changes the working directory to a subdirectory, `os.chdir(os.pardir)` will change it to the parent directory.  Just uncomment (and maybe multiply) the commands you need.

# %%
#os.chdir(os.pardir)                      # change to parent directory
#os.chdir(...)                            # change to subdirectory '...'
os.makedirs('metadata', exist_ok=True)    # make folder 'metadata'
os.chdir('metadata')                      # change to folder 'metadata'
print(os.getcwd())
# Out:
# C:\Users\kwoit\Documents\GitHub\e-rara-access\data\metadata

# %% [markdown]
# You might want to **download the metadata record directly** by its e-rara ID and in a specified metadata format. The `download_record()` function does this for you easily. If you choose no format, *MODS* will be delivered.

# %%
def download_record(ID, metadataPrefix='mods'):
    '''
    Downloads a certain metadata record from OAI to a single XML file.
    Throws a notice if metadata file already exists and leaves the existing one.
    Parameters:
    ID = E-rara ID of the wanted record.
    metadataPrefix = Metadata format to be delivered. Default value is MODS.
    '''
    path = os.getcwd()
    output_soup = load_xml({'verb': 'GetRecord', 'metadataPrefix': metadataPrefix, 'identifier': ID})
    outfile = path + '/{}.xml'.format(ID) 
    try:
        with open(outfile, mode='x', encoding='utf-8') as f:
            f.write(output_soup.decode())
            print("Metadata file {}.xml saved".format(ID))
    except FileExistsError:
            print("Metadata file {}.xml exists already".format(ID))
    finally:
            pass

# %%
# Example for downloading a single metadata record
# https://www.e-rara.ch/oai?verb=GetRecord&metadataPrefix=oai_dc&identifier=20329783

download_record(20329783, 'oai_dc')
# Out:
# Metadata file 20329783.xml saved

# %% [markdown]
# ### 2.3 Get set size & download metadata by set

# %% [markdown]
# Scraping the OAI interface output directly yields a problem with a bigger data volume. The output is **split into segments of ten records, which are presented on single webpages**. Looking at a sample request with `ListIdentifier` method, you will find the `resumptionToken` element, which on the one hand delivers the `completeListSize`, and on the other hand holds the resumption token. The [resumption token](http://www.openarchives.org/OAI/openarchivesprotocol.html#FlowControl) is required to access the next segment web page, which again includes a resumption token to the next page and so on.

# %%
# Scroll to the end of the page for the resumption token
IFrame('https://www.e-rara.ch/oai?verb=ListIdentifiers&set=russexil&metadataPrefix=oai_dc', width=970, height=300)
# Out:
#         <iframe
#             width="970"
#             height="300"
#             src="https://www.e-rara.ch/oai?verb=ListIdentifiers&set=russexil&metadataPrefix=oai_dc"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# We can use this information to define a function `setsize()` which reads out the size of a certain set.

# %%
def setsize(Set):  
    '''
    Accesses the OAI interface and retrieves the size of a given OAI set.
    Parameters:
    Set: The 'setSpec' short cut of the desired OAI set.
    '''
    base_url = oai
    listsearch_term = {'verb': 'ListIdentifiers', 'metadataPrefix': 'oai_dc', 'set': Set}
    
    # Basic function
    def load_xml(params):
        '''
        Accesses the OAI interface according to given parameters and scrapes its content.
        Parameters:
        All available native OAI verbs and parameter/value pairs.
        '''
        response = requests.get(base_url, params=params)
        output_soup = soup(response.content, "lxml")
        return output_soup
    
    xml_soup = load_xml(listsearch_term)
    if xml_soup.resumptiontoken:
        set_size = int(xml_soup.resumptiontoken['completelistsize'])
    else:
        set_size = len(xml_soup.find_all('identifier'))
    return set_size

# %%
setsize('russexil')
# Out:
# 320

# %% [markdown]
# With this function and recurring to the Polymatheia functions from the start it is also possible to **read out all the set sizes** of the OAI interface at once.

# %%
from polymatheia.data.reader import OAISetReader
from polymatheia.data.writer import PandasDFWriter

reader = OAISetReader(oai)
setspec = []                          
[setspec.append(x) for x in reader]                
df = PandasDFWriter().write(setspec)
df['setSize'] = df['setSpec']
for i in df.index:
    set_size = setsize(df.setSpec[i])
    df.setSize[i] = set_size
df.style
# Out:
# <style  type="text/css" >
# </style><table id="T_24d69fd0_d440_11eb_9f49_00090ffe0001" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >setSpec</th>        <th class="col_heading level0 col1" >setName</th>        <th class="col_heading level0 col2" >setSize</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_24d69fd0_d440_11eb_9f49_00090ffe0001level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_24d69fd0_d440_11eb_9f49_00090ffe0001row0_col0" class="data row0 col0" >frc_g</td>
#                         <td id="T_24d69fd0_d440_11eb_9f49_00090ffe0001row0_col1" class="data row0 col1" >BCU Fribourg (GLN)</td>
#                         <td id="T_24d69fd0_d440_11eb_9f49_00090ffe0001row0_col2" class="data row0 col2" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_24d69fd0_d440_11eb_9f49_00090ffe0001level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_24d69fd0_d440_11eb_9f49_00090ffe0001row1_col0" class="data row1 col0" >elibch</td>
#                         <td id="T_24d69fd0_d440_11eb_9f49_00090ffe0001row1_col1" class="data row1 col1" >Alle Bibliotheken</td>
#                         <td id="T_24d69fd0_d440_11eb_9f49_00090ffe0001row1_col2" class="data row1 col2" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_24d69fd0_d440_11eb_9f49_00090ffe0001level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_24d69fd0_d440_11eb_9f49_00090ffe0001row2_col0" class="data row2 col0" >zbs</td>
#                         <td id="T_24d69fd0_d440_11eb_9f49_00090ffe0001row2_col1" class="data row2 col1" >Zentralbibliothek Solothurn</td>
#                         <td id="T_24d69fd0_d440_11eb_9f49_00090ffe0001row2_col2" class="data row2 col2" >77</td>
#             </tr>
#             <tr>
#                         <th id="T_24d69fd0_d440_11eb_9f49_00090ffe0001level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_24d69fd0_d440_11eb_9f49_00090ffe0001row3_col0" class="data row3 col0" >sbs</td>
#                         <td id="T_24d69fd0_d440_11eb_9f49_00090ffe0001row3_col1" class="data row3 col1" >Stadtbibliothek Schaffhausen</td>
#                         <td id="T_24d69fd0_d440_11eb_9f49_00090ffe0001row3_col2" class="data row3 col2" >68</td>
#             </tr>
#             <tr>
#                         <th id="T_24d69fd0_d440_11eb_9f49_00090ffe0001level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_24d69fd0_d440_11eb_9f49_00090ffe0001row4_col0" class="data row4 col0" >astrorara</td>
#                         <td id="T_24d69fd0_d440_11eb_9f49_00090ffe0001row4_col1" class="data row4 col1" >Astronomie-rara</td>
#                         <td id="T_24d69fd0_d440_11eb_9f49_00090ffe0001row4_col2" class="data row4 col2" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_24d69fd0_d440_11eb_9f49_00090ffe0001level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_24d69fd0_d440_11eb_9f49_00090ffe0001row5_col0" class="data row5 col0" >bau_1</td>
#                         <td id="T_24d69fd0_d440_11eb_9f49_00090ffe0001row5_col1" class="data row5 col1" >UB Basel (DSV01)</td>
#                         <td id="T_24d69fd0_d440_11eb_9f49_00090ffe0001row5_col2" class="data row5 col2" >13185</td>
#             </tr>
#             <tr>
#                         <th id="T_24d69fd0_d440_11eb_9f49_00090ffe0001level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_24d69fd0_d440_11eb_9f49_00090ffe0001row6_col0" class="data row6 col0" >kbg</td>
#                         <td id="T_24d69fd0_d440_11eb_9f49_00090ffe0001row6_col1" class="data row6 col1" >Kantonsbibliothek Graubünden</td>
#                         <td id="T_24d69fd0_d440_11eb_9f49_00090ffe0001row6_col2" class="data row6 col2" >207</td>
#             </tr>
#             <tr>
#                         <th id="T_24d69fd0_d440_11eb_9f49_00090ffe0001level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_24d69fd0_d440_11eb_9f49_00090ffe0001row7_col0" class="data row7 col0" >nep_r</td>
#                         <td id="T_24d69fd0_d440_11eb_9f49_00090ffe0001row7_col1" class="data row7 col1" >Bibliothèque des Pasteurs, BPU Neuchâtel (RERO)</td>
#                         <td id="T_24d69fd0_d440_11eb_9f49_00090ffe0001row7_col2" class="data row7 col2" >9</td>
#             </tr>
#             <tr>
#                         <th id="T_24d69fd0_d440_11eb_9f49_00090ffe0001level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_24d69fd0_d440_11eb_9f49_00090ffe0001row8_col0" class="data row8 col0" >astrozut</td>
#                         <td id="T_24d69fd0_d440_11eb_9f49_00090ffe0001row8_col1" class="data row8 col1" >ETH-Bibliothek Zürich</td>
#                         <td id="T_24d69fd0_d440_11eb_9f49_00090ffe0001row8_col2" class="data row8 col2" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_24d69fd0_d440_11eb_9f49_00090ffe0001level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_24d69fd0_d440_11eb_9f49_00090ffe0001row9_col0" class="data row9 col0" >frc_r</td>
#                         <td id="T_24d69fd0_d440_11eb_9f49_00090ffe0001row9_col1" class="data row9 col1" >BCU Fribourg (RERO)</td>
#                         <td id="T_24d69fd0_d440_11eb_9f49_00090ffe0001row9_col2" class="data row9 col2" >46</td>
#             </tr>
#             <tr>
#                         <th id="T_24d69fd0_d440_11eb_9f49_00090ffe0001level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_24d69fd0_d440_11eb_9f49_00090ffe0001row10_col0" class="data row10 col0" >ebs</td>
#                         <td id="T_24d69fd0_d440_11eb_9f49_00090ffe0001row10_col1" class="data row10 col1" >Eisenbibliothek Schlatt</td>
#                         <td id="T_24d69fd0_d440_11eb_9f49_00090ffe0001row10_col2" class="data row10 col2" >103</td>
#             </tr>
#             <tr>
#                         <th id="T_24d69fd0_d440_11eb_9f49_00090ffe0001level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_24d69fd0_d440_11eb_9f49_00090ffe0001row11_col0" class="data row11 col0" >nep_g</td>
#                         <td id="T_24d69fd0_d440_11eb_9f49_00090ffe0001row11_col1" class="data row11 col1" >Bibliothèque des Pasteurs, BPU Neuchâtel (GLN)</td>
#                         <td id="T_24d69fd0_d440_11eb_9f49_00090ffe0001row11_col2" class="data row11 col2" >16</td>
#             </tr>
#             <tr>
#                         <th id="T_24d69fd0_d440_11eb_9f49_00090ffe0001level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_24d69fd0_d440_11eb_9f49_00090ffe0001row12_col0" class="data row12 col0" >lg1</td>
#                         <td id="T_24d69fd0_d440_11eb_9f49_00090ffe0001row12_col1" class="data row12 col1" >Biblioteca Salita dei Frati, Lugano</td>
#                         <td id="T_24d69fd0_d440_11eb_9f49_00090ffe0001row12_col2" class="data row12 col2" >353</td>
#             </tr>
#             <tr>
#                         <th id="T_24d69fd0_d440_11eb_9f49_00090ffe0001level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_24d69fd0_d440_11eb_9f49_00090ffe0001row13_col0" class="data row13 col0" >demusmu</td>
#                         <td id="T_24d69fd0_d440_11eb_9f49_00090ffe0001row13_col1" class="data row13 col1" >Deutsches Museum, München</td>
#                         <td id="T_24d69fd0_d440_11eb_9f49_00090ffe0001row13_col2" class="data row13 col2" >51</td>
#             </tr>
#             <tr>
#                         <th id="T_24d69fd0_d440_11eb_9f49_00090ffe0001level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_24d69fd0_d440_11eb_9f49_00090ffe0001row14_col0" class="data row14 col0" >ge88</td>
#                         <t

# %% [markdown]
# Because of the results splitting with resumption tokens it is a bit more complex to bulk download metadata directly from the OAI interface. With `retrieve_set_metadata()` we create a function to **retrieve  all metadata records of a set** in a certain format, and save the XML files to a designated folder.

# %%
print(os.getcwd())                        # print current working directory
# Out:
# C:\Users\kwoit\Documents\GitHub\e-rara-access\data\metadata

# %%
def retrieve_set_metadata(Set, foldername, metadataPrefix='mods'):
    '''
    Downloads metadata records of a given set and in a given format from OAI to XML files
    in a designated folder.
    Therefore it
    * requests e-rara OAI-PMH interface according to a set 
    * creates a folder for the records according to parameter foldername
    * retrieves the set's e-rara IDs
    * retrieves metadata according to IDs and given metadata format (default: MODS)
    * saves metadata to single <e-rara ID>.xml files in the folder.
    Parameters:
    Set = The 'setSpec' short cut of the desired OAI set.
    foldername = The name of the folder which will be created to hold the metadata files.
    metadataPrefix = Metadata format to be delivered. Default value is MODS.
    '''
    start = time.perf_counter()

    # Set parameters to the interface
    base_url = oai
    recordsearch_term = {'verb': 'GetRecord', 'metadataPrefix': metadataPrefix}
    listsearch_term = {'verb': 'ListIdentifiers', 'metadataPrefix': metadataPrefix, 'set': Set}
    
    # Make a folder <metadata> with subfolder named like the set to store files in it
    path = os.getcwd() + '/' + foldername
    try:
        os.makedirs(path, exist_ok = True)
        print("Path {} is already available or created successfully".format(path))
    except OSError as error:
        print("Path {} can not be created".format(path))
    
        
    # Basic functions
    def load_xml(params):
        '''
        Accesses the OAI interface according to given parameters and scrapes its content.
        '''
        response = requests.get(base_url, params=params)
        output_soup = soup(response.content, "lxml")
        return output_soup

    def download_record(ID):
        '''
        Downloads a certain metadata record from OAI to a single XML file.
        Throws a notice if metadata file already exists and leaves the existing one.
        Parameter:
        ID = E-rara ID of the desired record.
        '''
        output_soup = load_xml({'verb': 'GetRecord', 'metadataPrefix': metadataPrefix, 'identifier': ID})
        outfile = path + '/{}.xml'.format(ID) 
        try:
            with open(outfile, mode='x', encoding='utf-8') as f:
                    f.write(output_soup.decode())
        except FileExistsError:
                print("Metadata file {}.xml exists already".format(ID))
        finally:
                pass

    # Start with the first access to OAI interface - get the item IDs of a set
    xml_soup = load_xml(listsearch_term)

    # Calculate how many accesses it takes to go through all the pages of the results list, print notice
    splits = math.ceil(int(xml_soup.resumptiontoken['completelistsize']) // 10) + 1
    print(xml_soup.resumptiontoken['completelistsize'], 'identifiers to request in ', splits, 'data splits')
    

    for i in range(splits):
        if i == 0:
            # First access for item IDs - first page + information about whole length of results list
            xml_soup_new = load_xml(listsearch_term)      
        else:
            # Following accesses for item IDs
            xml_soup_new = load_xml({'verb': 'ListIdentifiers', 'resumptionToken': resumption_token})

        # Scraping out the e-rara IDs
        ids = [] 
        for ID in [(i.contents[0]) for i in xml_soup_new.find_all('identifier')]:
            match = re.search('oai:www.e-rara.ch:(\d+)', ID)      # extract the number following 'oai:www.e-rara.ch:'
            if match:
                ids.append(match.group(1))     # first parenthesized subgroup of group() = number

        # Download the MODS metadata records according to retrieved e-rara IDs
        print('Start retrieving metadata for e-rara IDs ', ids)  
        for ID in ids:
            download_record(ID)
        ids = []

        # Actualize the resumtpion token to retrieve the the next page
        try:
            new_token = xml_soup_new.find('resumptiontoken').get_text()
            resumption_token = new_token
            print('New resumption token:', resumption_token)
        except AttributeError:
            print('Reached end of IDs/results list')       # notice when last page is done
        finally:
            pass

    with os.scandir(path) as entries:
        count = 0
        for entry in entries:
            count += 1       
    print("{} metadata files in {}".format(count, path))
    finish = time.perf_counter()
    print("Finished in {} second(s)".format(round(finish - start, 2)))

# %%
# Just choose the appropriate set short cut, the desired folder name and metadata format
retrieve_set_metadata('snm', 'e-rara_Nationalmuseum', 'oai_dc')
# Out:
# Path C:\Users\kwoit\Documents\GitHub\e-rara-access\data\metadata/e-rara_Nationalmuseum is already available or created successfully
# 19 identifiers to request in  2 data splits
# Start retrieving metadata for e-rara IDs  ['19682232', '21806832', '19571743', '19571670', '19571862', '19571979', '19572108', '19668657', '19668871', '19668984']
# New resumption token: 0x17704e76c786fc03363ee26700362373-cursor_p_3D10_p_26set_p_3Dsnm_p_26metadataPrefix_p_3Doai_dc_p_26batch_size_p_3D11
# Start retrieving metadata for e-rara IDs  ['19669094', '19669201', '19669322', '19669447', '19669572', '19669648', '21807225', '24463697', '24463840']
# Reached end of IDs/results list
# 19 metadata files in C:\Users\kwoit\Documents\GitHub\e-rara-access\data\metadata/e-rara_Nationalmuseum
# Finished in 3.12 second(s)

# %% [markdown]
# ## 3 Download fulltext files from e-rara website

# %% [markdown]
# ### 3.0 Prerequisites

# %%
# Load the necessary libraries
import requests                                 # request URLs
from bs4 import BeautifulSoup as soup           # webscrape and parse HTML and XML
import lxml                                     # XML parser supported by bs4
                                                # call with soup(markup, 'lxml-xml' OR 'xml')
import os                                       # navigate and manipulate file directories
import time                                     # work with time stamps
import pandas as pd                             # pandas is the Python standard library to work with dataframes
from IPython.display import IFrame              # embed website views in jupyter notebook
import math                                     # work with mathematical functions
import re                                       # work with regular expressions
print("Successfully imported necessary libraries")
# Out:
# Successfully imported necessary libraries

# %% [markdown]
# https://www.e-rara.ch/oai/ will be the **base URL** for all OAI requests. To make life easier we put it into the variable `oai`.

# %%
oai = 'https://www.e-rara.ch/oai/'

# %% [markdown]
# ### 3.1 Download fulltext files by e-rara ID

# %% [markdown]
# Downloading e-rara fulltetxts can be done from the e-rara website. For e-rara items which have a fulltext file available, a link is provided in the *Links* > *Download* section of the item page.

# %%
IFrame('https://www.e-rara.ch/content/titleinfo/20329783', width=970, height=300)
# Out:
#         <iframe
#             width="970"
#             height="300"
#             src="https://www.e-rara.ch/content/titleinfo/20329783"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# At first, next to the `metadata` folder a new directory `fulltexts`will be created.

# %%
print(os.getcwd())                                # print current working directory
# Out:
# C:\Users\kwoit\Documents\GitHub\e-rara-access\data\metadata

# %% [markdown]
# In case you might change your directory you can easily do this with `os.chdir` or `os.chdir(os.pardir)`. While `os.chdir()` changes the working directory to a subdirectory, `os.chdir(os.pardir)` will change it to the parent directory.

# %%
os.chdir(os.pardir)                               # change to parent directory
os.makedirs('fulltexts', exist_ok=True)           # make new folder 'fulltexts'
os.chdir('fulltexts')                             # change to 'fulltexts' folder
print(os.getcwd())
# Out:
# C:\Users\kwoit\Documents\GitHub\e-rara-access\data\fulltexts

# %% [markdown]
# A single fulltext file can be retrieved by a given e-rara ID with the following function `download_fulltext()`. Note that **for fulltexts a different base URL**  - in combination with the given e-rara ID - has to be used: `https://www.e-rara.ch/download/fulltext/plain/`.

# %%
def download_fulltext(ID):
    '''
    Downloads a certain fulltext file of TXT format.
    Builds with e-rara ID the fulltext URL, reads the TXT and saves it to 
    <e-rara ID>.txt file on local disk.
    Parameter:
    ID = E-rara ID of the desired record.
    '''
    baseurl_fulltext = "https://www.e-rara.ch/download/fulltext/plain/"
    webadd = baseurl_fulltext + str(ID)
    response = requests.get(webadd) 
    soup_out = soup(response.text, 'html.parser')
    outfile = '{}.txt'.format(ID)
    
    try:
        with open(outfile, 'x', encoding='utf-8') as f:
            f.write(soup_out.get_text())
            print("Fulltext file {}.txt saved".format(ID))
    except FileExistsError:
        print("Fulltext file {}.txt exists already".format(ID))
    except:
        print("Saving fulltext file {}.txt failed".format(ID))
    finally:
        pass

# %%
# Retrieving example fulltexts by e-rara IDs
e_rara_ids = [20329783, 6156847, 6094442, 6125674]

for identifier in e_rara_ids: 
    download_fulltext(identifier)
# Out:
# Fulltext file 20329783.txt saved
# Fulltext file 6156847.txt saved
# Fulltext file 6094442.txt saved
# Fulltext file 6125674.txt saved

# %% [markdown]
# We might read the files then from local disk.

# %%
with open('20329783.txt', 'r', encoding='utf-8') as f:
    fulltext = f.read()
print(fulltext)
# Out:
# m. ‘ ■* ■VÆ:- \ wm ETH-Bibliothek EM000007324054 mm
#
# V A 'V MM MW I v-,v V. MiràSKKZ 8WKWWW Km'»? W« »Ü5E 2 » • WM **C '4M
#
# y .. ' . ä® 'S I V j' }' y I  l'xT' " \ ' ■ \ i Jf/Ayy x - . .. V .'AM V ^ ' y '' / A A W'^ ■ / a- X’ / V r 7 V S ; ' v r‘,.V \- /T'A 'V; V> A' vì'", A yA' ''. V.'; y\,V 'X '- 'À:V'V- ,\ T V';'* * ■:' 'j-\ - ^ y s^X_> ' l^'v ; , ’ y ' 7 ,s t J ' X T ? • ,: . : ■  r ; t, v .s'- t-y '- v ». tttA, :■> ■'' ' 7 ' 'TA>'T.i ■: i y- ! y ■' ■ '/■, y . \' .-‘y I , ' ;\- ■ ■ ‘/ \ y ;■ '} ^ /!  ' <. • y > \ V \C •' ' ' v . \ '' ' J ’ ' y <  . 1 \  ‘ L ' • 1 ■•' • • ■’ H V v V, ,; '  V ; vTy'V AA A a* \ aaa'ta x y. - - .'.V /;■ V ,,y y • ; N- ^ >• r‘vA- / ' fi K*** V < - , A A X ls~ ; .yAA ,y < j y yyx X / -, ' ' / , V. 'V ^ " v ■■• r y- '■ ■'  • 1 "°' ' ? . / • A/ A ' ; '-y y IV ■ ' t / ^ ^ ^ . \ ‘‘yyy ^^ ' ; -a,;-:';■'. 'VTy A if'T: y•: r • * A *.v / .. „y. *fisAA - , A - A; y ■ y ' v\ - Yy. ,, V .' 1 /ly./- ■■. ■ ' ! , / f * \ 1  ? /A' ,  i y - J. ■ !}■{■ v- -t , r '■ y, ï', ^V'. .. U,'" •y , V . ■ V' ■ : V . >y. •,; v -..'i. y -, \ ■ - yy--' /■S r- A- -y.
#
# \ s »% .Sfe-.?*r -S iWteiülc» £3S?3 MM *:3SSâ W 8 K M^gT »«3*î 'Mâ.v
#
# BIBLIOTHECA MAGICA ET PNEUMATICA.
#
# BIBLIOTHECA MAGICI ei PMJMATICA Wissenschaftlich geordnete Bibliographie der wichtigsten in das Gebiet des Zauber-, Wunder-, Geisterund sonstigen Aberglaubens vorzüglich älterer Zeit einschlagenden Werke. Mit Angabe der auS diesen Wissenschaften auf der Kvnigl. Sachs. Oeff. Bibliothek zu Dresden befindlichen Schriften. Ein löritrag ;ur fittengesehichtlichen Literatur. Zusammengestellt und mit einem doppelten Register versehen von vr. Johann Georg Theodor Graste, Bibliothekar Sr. Majestät des Königs von Sachsen. Leipzig, Verlag von Wilhelm Engelmann.
#
# •?K'K' à 'j K ,a : : ititi .'•• • l'y’-’n „ /Lc>  i , 4 - mi-o \a * V t 23. JUNI m
#
# Sr. Excellenz Herrn Gottlob Heinrich von Minckwitz, Königl. Sachs. Wirklichem Geheimen Rathe, Kämmerer, auch Ober-Hofmeister Ihrer Majestät der Königin, Grostkreuz des Königl. Sächs. Civ. Werd. Ordens, wie auch des Königl. Sicil. Constantinischen St. Georgen-Ordens und des Königl. Sardin« Mauritius- und Lazarus-Ordens und Ritter des Kaiser!. Ruff. St. Annen-Ordens erster Classe, wie auch des Königl. Preuß. rothen Adler- Ordens erster Classe, rc. rc. rc. seinem hochverehrten Gönner in tiefster Verehrung und Ergebenheit gewidmet.
#
# I?”
#
# mm • -, 7 ' 5 73 t & *.»5?'^ ,, F'
#
# ZMK V W.;v. „•'VSfx.v 7 ' ’-. vv ■HefSw&SSS: à'/ KX'M! »
#
# SWà-, iMmmmm •ì;^/ : «? a srs?' i âM WWT' îLLà
#
# 21*4
#
# / - J' A
#
# i, "A :k'l 1 '■'I y \x ! v . *
#
# v. y -SH •# i t L'jâl :-' 1 irfïK.'*^

# %% [markdown]
# But when we try to read another fulltext file from the download we face a severe problem: There is nothing!
# Here's the explanation: The file which was successfully downloaded *is* just an empty file. We might check this at source.
#
# Note that not all documents on the e-rara platform have an OCR-based fulltext file available.

# %%
# Empty file! Resulting from an empty fulltext page
with open('6125674.txt', 'r', encoding='utf-8') as f:
    fulltext = f.read()
fulltext
# Out:
# ''

# %%
# Looking at the source fulltext page online
IFrame('https://www.e-rara.ch/download/fulltext/plain/6125674', width=970, height=100)
# Out:
#         <iframe
#             width="970"
#             height="100"
#             src="https://www.e-rara.ch/download/fulltext/plain/6125674"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# So, if you **don't know which of the e-rara items have fulltext files available** and which not, there's the following way to get rid of the resulting empty files.

# %%
print(os.getcwd())                 # print current working directory
# Out:
# C:\Users\kwoit\Documents\GitHub\e-rara-access\data\fulltexts

# %%
# Delete empty files in the current working directory
path = os.getcwd()
count = 0
count_empty = 0
for entry in os.scandir(path):
    if os.path.getsize(entry) == 0:
        print("File {} is empty".format(entry.name))
        os.remove(entry.name)
        count_empty += 1
    else: 
        count += 1
        pass
print("{} empty fulltext files in {} deleted".format(count_empty, path))
print("{} fulltext files in {}".format(count, path))
# Out:
# File 6094442.txt is empty
# File 6125674.txt is empty
# 2 empty fulltext files in C:\Users\kwoit\Documents\GitHub\e-rara-access\data\fulltexts deleted
# 2 fulltext files in C:\Users\kwoit\Documents\GitHub\e-rara-access\data\fulltexts

# %% [markdown]
# ### 3.2 Download fulltext files by set

# %% [markdown]
# Finally, let's build a function `retrieve_set_fulltexts` to retrieve **all fulltexts of a certain e-rara set**. Note that also empty fulltext files are retrieved and stored in between, but cleaned up in the end.
#
# **WARNING**: Note that e-rara sets can be large, so better **check the set size** before starting the download.

# %%
def setsize(Set):  
    base_url = oai
    listsearch_term = {'verb': 'ListIdentifiers', 'metadataPrefix': 'oai_dc', 'set': Set}
    
    # Basic function
    def load_xml(params):
        '''
        Accesses the OAI interface according to given parameters and scrapes its content.
        '''
        response = requests.get(base_url, params=params)
        output_soup = soup(response.content, "lxml")
        return output_soup
    
    xml_soup = load_xml(listsearch_term)
    if xml_soup.resumptiontoken:
        set_size = int(xml_soup.resumptiontoken['completelistsize'])
    else:
        set_size = len(xml_soup.find_all('identifier'))
    return set_size

# %%
setsize('zhdk')
# Out:
# 31

# %%
def retrieve_set_fulltexts(Set, foldername):
    '''
    Downloads fulltext files of TXT format of a given OAI set to a certain folder.
    Builds with e-rara IDs the fulltext URLs, reads the TXT and saves them to 
    <e-rara ID>.txt files on local disk.
    Therefore it
    * requests e-rara OAI-PMH interface according to a set 
    * creates a folder according to parameter foldername
    * retrieves the set's e-rara IDs from OAI interface
    * retrieves fulltexts according to the IDs from e-rara website
    * writes fulltexts into single <e_rara_id>.txt files in the folder
    * finally checks all fulltext files in the folder if they are empty, and 
    deletes those empty files.
    Parameters:
    Set = The 'setSpec' short cut of the desired set.
    foldername = The name of the folder which will be created to hold the fulltext files.
    '''
    start = time.perf_counter()

    # Set parameters to the interface
    base_url = oai
    baseurl_fulltext = "https://www.e-rara.ch/download/fulltext/plain/"
    listsearch_term = {'verb': 'ListIdentifiers', 'metadataPrefix': 'oai_dc', 'set': Set}
    
    # Make a folder <fulltexts> with subfolder named like the set to store files in it
    path = os.getcwd() + '/' + foldername
    try:
        os.makedirs(path, exist_ok = True)
        print("Path {} is already available or created successfully".format(path))
    except OSError as error:
        print("Path {} cannot be created".format(path))
           
    # Basic functions
    def load_xml(params):
        '''
        Accesses the OAI interface according to given parameters and scrapes its content.
        '''
        response = requests.get(base_url, params=params)
        output_soup = soup(response.content, "lxml")
        return output_soup

    def download_fulltext(ID):
        '''
        Downloads fulltext from e-rara website to a single TXT file.
        Throws a notice if fulltext file already exists and leaves it.
        Parameter:
        ID = E-rara ID of the desired record.
        '''
        webadd = baseurl_fulltext + str(ID)
        response = requests.get(webadd) 
        soup_out = soup(response.text, 'html.parser')
        outfile = path + '/{}.txt'.format(ID) 
        try:
            with open(outfile, 'w', encoding='utf-8') as f:
                f.write(soup_out.get_text())
                print("Fulltext file {}.txt saved".format(ID))
        except FileExistsError:
            print("Fulltext file {}.txt exists already".format(ID))
        except:
            print("Saving fulltext file {}.txt failed".format(ID))
        finally:
                pass
            
    # Start with the first access to OAI interface
    xml_soup = load_xml(listsearch_term)

    # Calculate how many accesses it takes to go through all the pages of the results list, print notice
    splits = math.ceil(int(xml_soup.resumptiontoken['completelistsize']) // 10) + 1
    print(xml_soup.resumptiontoken['completelistsize'], 'identifiers to request in ', splits, 'data splits')
            
            
    for i in range(splits):
        if i == 0:
            # First access to OAI for e-rara IDs - first page + information about whole length of results list
            xml_soup_new = load_xml(listsearch_term)      
        else:
            # Following accesses to OAI for e-rara IDs
            xml_soup_new = load_xml({'verb': 'ListIdentifiers', 'resumptionToken': resumption_token})

        # Scraping out the e-rara IDs
        e_rara_ids = [] 
        for e_rara_id in [(i.contents[0]) for i in xml_soup_new.find_all('identifier')]:
            match = re.search('oai:www.e-rara.ch:(\d+)', e_rara_id) # extract number following 'oai:www.e-rara.ch:'
            if match:
                e_rara_ids.append(match.group(1))       # first parenthesized subgroup of group() = number

        # Download the fulltexts according to retrieved e-rara IDs
        print('Start retrieving fulltetxts for e-rara IDs ', e_rara_ids) 
        for e_rara_id in e_rara_ids:
            download_fulltext(e_rara_id)
        e_rara_ids = []

        # Actualize the resumption token to retrieve the the next page
        try:
            new_token = xml_soup_new.find('resumptiontoken').get_text()
            resumption_token = new_token
            print('New resumption token:', resumption_token)
        except AttributeError:
            print('Reached end of IDs/results list')       # notice when last page is done
        finally:
            pass
        
    # Clean up empty files
    count = 0
    count_empty = 0
    for entry in os.scandir(path):
        if os.path.getsize(entry) == 0:
            print("File {} is empty".format(entry.name))
            os.remove(path + '/' + entry.name)
            count_empty += 1
        else: 
            count += 1
    print("{} empty fulltext file(s) in {} deleted".format(count_empty, path))
    print("{} fulltext file(s) in {}".format(count, path))

    finish = time.perf_counter()
    print("Finished in {} second(s)".format(round(finish - start, 2)))

# %%
retrieve_set_fulltexts('zhdk', 'e-rara_ZHDK')
# Out:
# Path C:\Users\kwoit\Documents\GitHub\e-rara-access\data\fulltexts/e-rara_ZHDK is already available or created successfully
# 31 identifiers to request in  4 data splits
# Start retrieving fulltetxts for e-rara IDs  ['24464158', '24464392', '24464517', '24464637', '24537418', '24537593', '24537791', '24538034', '24770753', '24770918']
# Fulltext file 24464158.txt saved
# Fulltext file 24464392.txt saved
# Fulltext file 24464517.txt saved
# Fulltext file 24464637.txt saved
# Fulltext file 24537418.txt saved
# Fulltext file 24537593.txt saved
# Fulltext file 24537791.txt saved
# Fulltext file 24538034.txt saved
# Fulltext file 24770753.txt saved
# Fulltext file 24770918.txt saved
# New resumption token: 0x29c03ab5a09eaf8245bf06f379f4c64a-cursor_p_3D10_p_26set_p_3Dzhdk_p_26metadataPrefix_p_3Doai_dc_p_26batch_size_p_3D11
# Start retrieving fulltetxts for e-rara IDs  ['24771232', '24771517', '24567987', '24573367', '24573559', '24573632', '24573804', '24573911', '24764534', '24765325']
# Fulltext file 24771232.txt saved
# Fulltext file 24771517.txt saved
# Fulltext file 24567987.txt saved
# Fulltext file 24573367.txt saved
# Fulltext file 24573559.txt saved
# Fulltext file 24573632.txt saved
# Fulltext file 24573804.txt saved
# Fulltext file 24573911.txt saved
# Fulltext file 24764534.txt saved
# Fulltext file 24765325.txt saved
# New resumption token: 0x665483aaf1939cf6735640a43588eb1f-cursor_p_3D20_p_26set_p_3Dzhdk_p_26metadataPrefix_p_3Doai_dc_p_26batch_size_p_3D11
# Start retrieving fulltetxts for e-rara IDs  ['24681434', '24684623', '24685154', '24685320', '24687864', '24765621', '24766084', '24767057', '24771914', '24772163']
# Fulltext file 24681434.txt saved
# Fulltext file 24684623.txt saved
# Fulltext file 24685154.txt saved
# Fulltext file 24685320.txt saved
# Fulltext file 24687864.txt saved
# Fulltext file 24765621.txt saved
# Fulltext file 24766084.txt saved
# Fulltext file 24767057.txt saved
# Fulltext file 24771914.txt saved
# Fulltext file 24772163.txt saved
# New resumption token: 0x665483aaf1939cf6735640a43588eb1f-cursor_p_3D30_p_26set_p_3Dzhdk_p_26metadataPrefix_p_3Doai_dc_p_26batch_size_p_3D11
# Start retrieving fulltetxts for e-rara IDs  ['24772266']
# Fulltext file 24772266.txt saved
# Reached end of IDs/results list
# File 24464158.txt is empty
# File 24537791.txt is empty
# File 24538034.txt is empty
# File 24567987.txt is empty
# File 24573367.txt is empty
# File 24573911.txt is empty
# File 24764534.txt is empty
# File 24766084.txt is empty
# File 24767057.txt is empty
# File 24770753.txt is empty
# File 24770918.txt is empty
# File 24771914.txt is empty
# File 24772163.txt is empty
# 13 empty fulltext file(s) in C:\Users\kwoit\Documents\GitHub\e-rara-access\data\fulltexts/e-rara_ZHDK deleted
# 18 fulltext file(s) in C:\Users\kwoit\Documents\GitHub\e-rara-access\data\fulltexts/e-rara_ZHDK
# Finished in 24.75 second(s)
